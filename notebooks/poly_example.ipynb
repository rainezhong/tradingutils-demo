# %%
import sys
import os

module_dir = '../poly_utils'
absolute_module_dir = os.path.abspath(module_dir)

if absolute_module_dir not in sys.path:
    sys.path.insert(0, absolute_module_dir)
    
from poly_utils.poly_wrapper import PolymarketWrapped

poly = PolymarketWrapped()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 10
#       7 if absolute_module_dir not in sys.path:
#       8     sys.path.insert(0, absolute_module_dir)
# ---> 10 from poly_utils.poly_wrapper import PolymarketWrapped
#      12 poly = PolymarketWrapped()
#
# ModuleNotFoundError: No module named 'poly_utils'
