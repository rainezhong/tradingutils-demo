# %%
import sys
import os
# Add parent directory to path to import tradingutils modules
sys.path.insert(0, os.path.abspath('..'))

from kalshi_utils.client_wrapper import *

kalshi_wrapped = KalshiWrapped()

nba_live_markets = kalshi_wrapped.GetALLNBAMarkets(status="open")
nhl_live_markets = kalshi_wrapped.GetAllNHLMarkets(status="open")
college_markets = kalshi_wrapped.GetALLNCAAMBMarkets(status="open")

pairs = kalshi_wrapped.GetMarketPairs(nba_live_markets)
# Out:
# Client Created

# %%
pairs
# Out:
# [(Market(ticker='KXNBAGAME-26JAN22MIAPOR-POR', event_ticker='KXNBAGAME-26JAN22MIAPOR', market_type='binary', title='Miami at Portland Winner?', subtitle='', yes_sub_title='Portland', no_sub_title='Portland', created_time=datetime.datetime(2026, 1, 20, 14, 3, 4, 696174, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 19, 7, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 3, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 6, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 3, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 3, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=52, yes_bid_dollars='0.5200', yes_ask=55, yes_ask_dollars='0.5500', no_bid=45, no_bid_dollars='0.4500', no_ask=48, no_ask_dollars='0.4800', last_price=55, last_price_dollars='0.5500', volume=142, volume_24h=122, result='', can_close_early=True, open_interest=142, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=3230446, liquidity_dollars='32304.4600', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '2229b01e-68eb-46ad-adf4-71a9533c84fc'}, rules_primary='If Portland wins the Miami at Portland professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNBAGAME-26JAN22MIAPOR-MIA', event_ticker='KXNBAGAME-26JAN22MIAPOR', market_type='binary', title='Miami at Portland Winner?', subtitle='', yes_sub_title='Miami', no_sub_title='Miami', created_time=datetime.datetime(2026, 1, 20, 14, 3, 4, 696174, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 19, 7, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 3, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 6, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 3, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 3, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=45, yes_bid_dollars='0.4500', yes_ask=49, yes_ask_dollars='0.4900', no_bid=51, no_bid_dollars='0.5100', no_ask=55, no_ask_dollars='0.5500', last_price=49, last_price_dollars='0.4900', volume=71, volume_24h=71, result='', can_close_early=True, open_interest=71, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=5865434, liquidity_dollars='58654.3400', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': 'a17e4a68-2999-4f60-b67e-3e80aa9e198b'}, rules_primary='If Miami wins the Miami at Portland professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNBAGAME-26JAN22LALLAC-LAL', event_ticker='KXNBAGAME-26JAN22LALLAC', market_type='binary', title='Los Angeles L at Los Angeles C Winner?', subtitle='', yes_sub_title='Los Angeles L', no_sub_title='Los Angeles L', created_time=datetime.datetime(2026, 1, 20, 14, 3, 0, 321107, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 19, 7, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 3, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 6, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 3, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 3, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=56, yes_bid_dollars='0.5600', yes_ask=59, yes_ask_dollars='0.5900', no_bid=41, no_bid_dollars='0.4100', no_ask=44, no_ask_dollars='0.4400', last_price=59, last_price_dollars='0.5900', volume=405, volume_24h=405, result='', can_close_early=True, open_interest=352, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=5977831, liquidity_dollars='59778.3100', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '2ef4d31c-0b46-4f43-a403-f44d62489034'}, rules_primary='If Los Angeles L wins the Los Angeles L at Los Angeles C professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNBAGAME-26JAN22LALLAC-LAC', event_ticker='KXNBAGAME-26JAN22LALLAC', market_type='binary', title='Los Angeles L at Los Angeles C Winner?', subtitle='', yes_sub_title='Los Angeles C', no_sub_title='Los Angeles C', created_time=datetime.datetime(2026, 1, 20, 14, 3, 0, 321107, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 19, 7, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 3, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 6, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 3, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 3, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=43, yes_bid_dollars='0.4300', yes_ask=44, yes_ask_dollars='0.4400', no_bid=56, no_bid_dollars='0.5600', no_ask=57, no_ask_dollars='0.5700', last_price=44, last_price_dollars='0.4400', volume=168, volume_24h=168, result='', can_close_early=True, open_interest=168, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=3235964, liquidity_dollars='32359.6400', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': 'daca4413-0ea1-4db2-a815-f05c181ef0a6'}, rules_primary='If Los Angeles C wins the Los Angeles L at Los Angeles C professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNBAGAME-26JAN22SASUTA-UTA', event_ticker='KXNBAGAME-26JAN22SASUTA', market_type='binary', title='San Antonio at Utah Winner?', subtitle='', yes_sub_title='Utah', no_sub_title='Utah', created_time=datetime.datetime(2026, 1, 20, 14, 3, 0, 21029, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 19, 7, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 2, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 5, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 2, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 2, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=19, yes_bid_dollars='0.1900', yes_ask=21, yes_ask_dollars='0.2100', no_bid=79, no_bid_dollars='0.7900', no_ask=81, no_ask_dollars='0.8100', last_price=21, last_price_dollars='0.2100', volume=855, volume_24h=821, result='', can_close_early=True, open_interest=850, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=5873280, liquidity_dollars='58732.8000', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '6f60dfb1-fda1-423f-b76f-67e9d24b9644'}, rules_primary='If Utah wins the San Antonio at Utah professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNBAGAME-26JAN22SASUTA-SAS', event_ticker='KXNBAGAME-26JAN22SASUTA', market_type='binary', title='San Antonio at Utah Winner?', subtitle='', yes_sub_title='San Antonio', no_sub_title='San Antonio', created_time=datetime.datetime(2026, 1, 20, 14, 3, 0, 21029, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 19, 7, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 2, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 5, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 2, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 2, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=81, yes_bid_dollars='0.8100', yes_ask=82, yes_ask_dollars='0.8200', no_bid=18, no_bid_dollars='0.1800', no_ask=19, no_ask_dollars='0.1900', last_price=82, last_price_dollars='0.8200', volume=768, volume_24h=768, result='', can_close_early=True, open_interest=766, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=6172712, liquidity_dollars='61727.1200', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': 'ad36c3e8-4194-4e63-920f-7c50f46191a6'}, rules_primary='If San Antonio wins the San Antonio at Utah professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNBAGAME-26JAN22CHAORL-ORL', event_ticker='KXNBAGAME-26JAN22CHAORL', market_type='binary', title='Charlotte at Orlando Winner?', subtitle='', yes_sub_title='Orlando', no_sub_title='Orlando', created_time=datetime.datetime(2026, 1, 20, 11, 1, 36, 960253, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 16, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=66, yes_bid_dollars='0.6600', yes_ask=67, yes_ask_dollars='0.6700', no_bid=33, no_bid_dollars='0.3300', no_ask=34, no_ask_dollars='0.3400', last_price=67, last_price_dollars='0.6700', volume=376, volume_24h=376, result='', can_close_early=True, open_interest=375, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=11923148, liquidity_dollars='119231.4800', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '00c3e69d-d9b9-4ac3-bf79-19707fe43637'}, rules_primary='If Orlando wins the Charlotte at Orlando professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNBAGAME-26JAN22CHAORL-CHA', event_ticker='KXNBAGAME-26JAN22CHAORL', market_type='binary', title='Charlotte at Orlando Winner?', subtitle='', yes_sub_title='Charlotte', no_sub_title='Charlotte', created_time=datetime.datetime(2026, 1, 20, 11, 1, 36, 960253, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 16, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=35, yes_bid_dollars='0.3500', yes_ask=36, yes_ask_dollars='0.3600', no_bid=64, no_bid_dollars='0.6400', no_ask=65, no_ask_dollars='0.6500', last_price=36, last_price_dollars='0.3600', volume=94, volume_24h=94, result='', can_close_early=True, open_interest=72, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=8514741, liquidity_dollars='85147.4100', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '7c980c51-fa76-4571-b165-242b2a00f3a1'}, rules_primary='If Charlotte wins the Charlotte at Orlando professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNBAGAME-26JAN22GSWDAL-GSW', event_ticker='KXNBAGAME-26JAN22GSWDAL', market_type='binary', title='Golden State at Dallas Winner?', subtitle='', yes_sub_title='Golden State', no_sub_title='Golden State', created_time=datetime.datetime(2026, 1, 20, 11, 1, 36, 645104, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 16, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 30, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 30, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 30, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 30, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=57, yes_bid_dollars='0.5700', yes_ask=59, yes_ask_dollars='0.5900', no_bid=41, no_bid_dollars='0.4100', no_ask=43, no_ask_dollars='0.4300', last_price=59, last_price_dollars='0.5900', volume=486, volume_24h=486, result='', can_close_early=True, open_interest=472, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=12049494, liquidity_dollars='120494.9400', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '502c629b-4da7-40fd-92ab-20cb55411c35'}, rules_primary='If Golden State wins the Golden State at Dallas professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNBAGAME-26JAN22GSWDAL-DAL', event_ticker='KXNBAGAME-26JAN22GSWDAL', market_type='binary', title='Golden State at Dallas Winner?', subtitle='', yes_sub_title='Dallas', no_sub_title='Dallas', created_time=datetime.datetime(2026, 1, 20, 11, 1, 36, 645104, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 16, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 30, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 30, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 30, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 30, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=41, yes_bid_dollars='0.4100', yes_ask=43, yes_ask_dollars='0.4300', no_bid=57, no_bid_dollars='0.5700', no_ask=59, no_ask_dollars='0.5900', last_price=43, last_price_dollars='0.4300', volume=2278, volume_24h=2278, result='', can_close_early=True, open_interest=2264, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=12363937, liquidity_dollars='123639.3700', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '36547ae6-f0fa-4d06-a6e5-5bfa64a217ed'}, rules_primary='If Dallas wins the Golden State at Dallas professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNBAGAME-26JAN22CHIMIN-MIN', event_ticker='KXNBAGAME-26JAN22CHIMIN', market_type='binary', title='Chicago at Minnesota Winner?', subtitle='', yes_sub_title='Minnesota', no_sub_title='Minnesota', created_time=datetime.datetime(2026, 1, 20, 11, 1, 36, 491321, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 16, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 4, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=71, yes_bid_dollars='0.7100', yes_ask=75, yes_ask_dollars='0.7500', no_bid=25, no_bid_dollars='0.2500', no_ask=29, no_ask_dollars='0.2900', last_price=74, last_price_dollars='0.7400', volume=650, volume_24h=650, result='', can_close_early=True, open_interest=646, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=9931329, liquidity_dollars='99313.2900', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '29e3c04e-fadb-4006-be20-cbb8c159ce0e'}, rules_primary='If Minnesota wins the Chicago at Minnesota professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNBAGAME-26JAN22CHIMIN-CHI', event_ticker='KXNBAGAME-26JAN22CHIMIN', market_type='binary', title='Chicago at Minnesota Winner?', subtitle='', yes_sub_title='Chicago', no_sub_title='Chicago', created_time=datetime.datetime(2026, 1, 20, 11, 1, 36, 491321, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 16, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 4, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=27, yes_bid_dollars='0.2700', yes_ask=28, yes_ask_dollars='0.2800', no_bid=72, no_bid_dollars='0.7200', no_ask=73, no_ask_dollars='0.7300', last_price=28, last_price_dollars='0.2800', volume=270, volume_24h=270, result='', can_close_early=True, open_interest=267, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=12551532, liquidity_dollars='125515.3200', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '65f0250b-455d-43d7-b7dc-7d321bdf9abc'}, rules_primary='If Chicago wins the Chicago at Minnesota professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNBAGAME-26JAN22HOUPHI-PHI', event_ticker='KXNBAGAME-26JAN22HOUPHI', market_type='binary', title='Houston at Philadelphia Winner?', subtitle='', yes_sub_title='Philadelphia', no_sub_title='Philadelphia', created_time=datetime.datetime(2026, 1, 20, 11, 1, 36, 248438, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 16, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=39, yes_bid_dollars='0.3900', yes_ask=46, yes_ask_dollars='0.4600', no_bid=54, no_bid_dollars='0.5400', no_ask=61, no_ask_dollars='0.6100', last_price=46, last_price_dollars='0.4600', volume=136, volume_24h=136, result='', can_close_early=True, open_interest=136, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=8786242, liquidity_dollars='87862.4200', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '0554528d-586b-461f-827b-801cf93e8a8e'}, rules_primary='If Philadelphia wins the Houston at Philadelphia professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNBAGAME-26JAN22HOUPHI-HOU', event_ticker='KXNBAGAME-26JAN22HOUPHI', market_type='binary', title='Houston at Philadelphia Winner?', subtitle='', yes_sub_title='Houston', no_sub_title='Houston', created_time=datetime.datetime(2026, 1, 20, 11, 1, 36, 248438, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 16, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=52, yes_bid_dollars='0.5200', yes_ask=57, yes_ask_dollars='0.5700', no_bid=43, no_bid_dollars='0.4300', no_ask=48, no_ask_dollars='0.4800', last_price=58, last_price_dollars='0.5800', volume=551, volume_24h=551, result='', can_close_early=True, open_interest=532, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=11477794, liquidity_dollars='114777.9400', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': 'a8625e4b-4ae6-4062-a7c1-0b6e1f4ae211'}, rules_primary='If Houston wins the Houston at Philadelphia professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNBAGAME-26JAN22DENWAS-WAS', event_ticker='KXNBAGAME-26JAN22DENWAS', market_type='binary', title='Denver at Washington Winner?', subtitle='', yes_sub_title='Washington', no_sub_title='Washington', created_time=datetime.datetime(2026, 1, 20, 11, 1, 35, 937439, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 16, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=30, yes_bid_dollars='0.3000', yes_ask=33, yes_ask_dollars='0.3300', no_bid=67, no_bid_dollars='0.6700', no_ask=70, no_ask_dollars='0.7000', last_price=31, last_price_dollars='0.3100', volume=255, volume_24h=255, result='', can_close_early=True, open_interest=89, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=11913100, liquidity_dollars='119131.0000', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '0464e75c-8bc8-4f18-9ee2-577832b889d6'}, rules_primary='If Washington wins the Denver at Washington professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNBAGAME-26JAN22DENWAS-DEN', event_ticker='KXNBAGAME-26JAN22DENWAS', market_type='binary', title='Denver at Washington Winner?', subtitle='', yes_sub_title='Denver', no_sub_title='Denver', created_time=datetime.datetime(2026, 1, 20, 11, 1, 35, 937439, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 16, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=69, yes_bid_dollars='0.6900', yes_ask=71, yes_ask_dollars='0.7100', no_bid=29, no_bid_dollars='0.2900', no_ask=31, no_ask_dollars='0.3100', last_price=71, last_price_dollars='0.7100', volume=1562, volume_24h=1562, result='', can_close_early=True, open_interest=1542, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=13370265, liquidity_dollars='133702.6500', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': 'ba2cb6be-9827-46a8-8e6f-d8661307ba77'}, rules_primary='If Denver wins the Denver at Washington professional basketball game originally scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNBAGAME-26JAN21TORSAC-TOR', event_ticker='KXNBAGAME-26JAN21TORSAC', market_type='binary', title='Toronto at Sacramento Winner?', subtitle='', yes_sub_title='Toronto', no_sub_title='Toronto', created_time=datetime.datetime(2026, 1, 19, 14, 2, 49, 426795, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 19, 19, 7, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 5, 3, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 22, 6, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 5, 3, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 5, 3, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=64, yes_bid_dollars='0.6400', yes_ask=65, yes_ask_dollars='0.6500', no_bid=35, no_bid_dollars='0.3500', no_ask=36, no_ask_dollars='0.3600', last_price=66, last_price_dollars='0.6600', volume=6810, volume_24h=6434, result='', can_close_early=True, open_interest=6700, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=61, previous_yes_bid_dollars='0.6100', previous_yes_ask=63, previous_yes_ask_dollars='0.6300', previous_price=61, previous_price_dollars='0.6100', liquidity=353990574, liquidity_dollars='3539905.7400', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '96c447dd-2cdd-4c58-a151-ef0df87de981'}, rules_primary='If Toronto wins the Toronto at Sacramento professional basketball game originally scheduled for Jan 21, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNBAGAME-26JAN21TORSAC-SAC', event_ticker='KXNBAGAME-26JAN21TORSAC', market_type='binary', title='Toronto at Sacramento Winner?', subtitle='', yes_sub_title='Sacramento', no_sub_title='Sacramento', created_time=datetime.datetime(2026, 1, 19, 14, 2, 49, 426795, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 19, 19, 7, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 5, 3, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 22, 6, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 5, 3, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 5, 3, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=35, yes_bid_dollars='0.3500', yes_ask=36, yes_ask_dollars='0.3600', no_bid=64, no_bid_dollars='0.6400', no_ask=65, no_ask_dollars='0.6500', last_price=35, last_price_dollars='0.3500', volume=2414, volume_24h=2393, result='', can_close_early=True, open_interest=2294, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=38, previous_yes_bid_dollars='0.3800', previous_yes_ask=39, previous_yes_ask_dollars='0.3900', previous_price=39, previous_price_dollars='0.3900', liquidity=352921320, liquidity_dollars='3529213.2000', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': 'ab9e2e9a-3243-41b6-a291-95f4d9c6edf7'}, rules_primary='If Sacramento wins the Toronto at Sacramento professional basketball game originally scheduled for Jan 21, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNBAGAME-26JAN21OKCMIL-OKC', event_ticker='KXNBAGAME-26JAN21OKCMIL', market_type='binary', title='Oklahoma City at Milwaukee Winner?', subtitle='', yes_sub_title='Oklahoma City', no_sub_title='Oklahoma City', created_time=datetime.datetime(2026, 1, 19, 14, 2, 49, 332378, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 19, 19, 7, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 22, 5, 30, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=77, yes_bid_dollars='0.7700', yes_ask=78, yes_ask_dollars='0.7800', no_bid=22, no_bid_dollars='0.2200', no_ask=23, no_ask_dollars='0.2300', last_price=78, last_price_dollars='0.7800', volume=23088, volume_24h=21860, result='', can_close_early=True, open_interest=22670, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=71, previous_yes_bid_dollars='0.7100', previous_yes_ask=80, previous_yes_ask_dollars='0.8000', previous_price=80, previous_price_dollars='0.8000', liquidity=318030454, liquidity_dollars='3180304.5400', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': 'a85f6eca-2f3b-4f61-83ab-8d049f59ce2c'}, rules_primary='If Oklahoma City wins the Oklahoma City at Milwaukee professional basketball game originally scheduled for Jan 21, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNBAGAME-26JAN21OKCMIL-MIL', event_ticker='KXNBAGAME-26JAN21OKCMIL', market_type='binary', title='Oklahoma City at Milwaukee Winner?', subtitle='', yes_sub_title='Milwaukee', no_sub_title='Milwaukee', created_time=datetime.datetime(2026, 1, 19, 14, 2, 49, 332378, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 19, 19, 7, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 22, 5, 30, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=22, yes_bid_dollars='0.2200', yes_ask=23, yes_ask_dollars='0.2300', no_bid=77, no_bid_dollars='0.7700', no_ask=78, no_ask_dollars='0.7800', last_price=23, last_price_dollars='0.2300', volume=21618, volume_24h=20841, result='', can_close_early=True, open_interest=21023, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=18, previous_yes_bid_dollars='0.1800', previous_yes_ask=22, previous_yes_ask_dollars='0.2200', previous_price=21, previous_price_dollars='0.2100', liquidity=313085262, liquidity_dollars='3130852.6200', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '5dc3fe01-79a4-4f2f-a953-d922ea4a6dd3'}, rules_primary='If Milwaukee wins the Oklahoma City at Milwaukee professional basketball game originally scheduled for Jan 21, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNBAGAME-26JAN21DETNOP-NOP', event_ticker='KXNBAGAME-26JAN21DETNOP', market_type='binary', title='Detroit at New Orleans Winner?', subtitle='', yes_sub_title='New Orleans', no_sub_title='New Orleans', created_time=datetime.datetime(2026, 1, 19, 11, 1, 58, 849961, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 19, 16, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 5, 1, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 22, 4, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 5, 1, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 5, 1, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=22, yes_bid_dollars='0.2200', yes_ask=23, yes_ask_dollars='0.2300', no_bid=77, no_bid_dollars='0.7700', no_ask=78, no_ask_dollars='0.7800', last_price=23, last_price_dollars='0.2300', volume=13443, volume_24h=13165, result='', can_close_early=True, open_interest=12822, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=23, previous_yes_bid_dollars='0.2300', previous_yes_ask=24, previous_yes_ask_dollars='0.2400', previous_price=24, previous_price_dollars='0.2400', liquidity=258275535, liquidity_dollars='2582755.3500', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': 'd3c8c2ac-c4a0-4d67-8b16-53cb91118dfc'}, rules_primary='If New Orleans wins the Detroit at New Orleans professional basketball game originally scheduled for Jan 21, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNBAGAME-26JAN21DETNOP-DET', event_ticker='KXNBAGAME-26JAN21DETNOP', market_type='binary', title='Detroit at New Orleans Winner?', subtitle='', yes_sub_title='Detroit', no_sub_title='Detroit', created_time=datetime.datetime(2026, 1, 19, 11, 1, 58, 849961, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 19, 16, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 5, 1, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 22, 4, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 5, 1, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 5, 1, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=78, yes_bid_dollars='0.7800', yes_ask=79, yes_ask_dollars='0.7900', no_bid=21, no_bid_dollars='0.2100', no_ask=22, no_ask_dollars='0.2200', last_price=79, last_price_dollars='0.7900', volume=23791, volume_24h=21923, result='', can_close_early=True, open_interest=22948, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=76, previous_yes_bid_dollars='0.7600', previous_yes_ask=77, previous_yes_ask_dollars='0.7700', previous_price=77, previous_price_dollars='0.7700', liquidity=263014698, liquidity_dollars='2630146.9800', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '65569528-1888-40aa-9d62-2b0e8142a9b4'}, rules_primary='If Detroit wins the Detroit at New Orleans professional basketball game originally scheduled for Jan 21, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNBAGAME-26JAN21ATLMEM-MEM', event_ticker='KXNBAGAME-26JAN21ATLMEM', market_type='binary', title='Atlanta at Memphis Winner?', subtitle='', yes_sub_title='Memphis', no_sub_title='Memphis', created_time=datetime.datetime(2026, 1, 19, 11, 1, 53, 233575, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 19, 16, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 5, 1, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 22, 4, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 5, 1, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 5, 1, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=56, yes_bid_dollars='0.5600', yes_ask=57, yes_ask_dollars='0.5700', no_bid=43, no_bid_dollars='0.4300', no_ask=44, no_ask_dollars='0.4400', last_price=57, last_price_dollars='0.5700', volume=6882, volume_24h=6037, result='', can_close_early=True, open_interest=6867, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=55, previous_yes_bid_dollars='0.5500', previous_yes_ask=61, previous_yes_ask_dollars='0.6100', previous_price=55, previous_price_dollars='0.5500', liquidity=366765299, liquidity_dollars='3667652.9900', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '1cfe70b8-4dfc-47dc-acca-b68d4a725972'}, rules_primary='If Memphis wins the Atlanta at Memphis professional basketball game originally scheduled for Jan 21, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
# ...
#   Market(ticker='KXNBAGAME-26JAN21CLECHA-CHA', event_ticker='KXNBAGAME-26JAN21CLECHA', market_type='binary', title='Cleveland at Charlotte Winner?', subtitle='', yes_sub_title='Charlotte', no_sub_title='Charlotte', created_time=datetime.datetime(2026, 1, 19, 11, 1, 51, 423110, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 19, 16, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 5, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 22, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 5, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 5, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=43, yes_bid_dollars='0.4300', yes_ask=44, yes_ask_dollars='0.4400', no_bid=56, no_bid_dollars='0.5600', no_ask=57, no_ask_dollars='0.5700', last_price=44, last_price_dollars='0.4400', volume=7268, volume_24h=7018, result='', can_close_early=True, open_interest=6336, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=40, previous_yes_bid_dollars='0.4000', previous_yes_ask=41, previous_yes_ask_dollars='0.4100', previous_price=41, previous_price_dollars='0.4100', liquidity=328589293, liquidity_dollars='3285892.9300', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '7c980c51-fa76-4571-b165-242b2a00f3a1'}, rules_primary='If Charlotte wins the Cleveland at Charlotte professional basketball game originally scheduled for Jan 21, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNBAGAME-26JAN20MIASAC-SAC', event_ticker='KXNBAGAME-26JAN20MIASAC', market_type='binary', title='Miami at Sacramento Winner?', subtitle='', yes_sub_title='Sacramento', no_sub_title='Sacramento', created_time=datetime.datetime(2026, 1, 18, 14, 1, 58, 292396, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 18, 19, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 21, 6, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=0, yes_bid_dollars='0.0000', yes_ask=1, yes_ask_dollars='0.0100', no_bid=99, no_bid_dollars='0.9900', no_ask=100, no_ask_dollars='1.0000', last_price=1, last_price_dollars='0.0100', volume=1776695, volume_24h=1647654, result='', can_close_early=True, open_interest=1139293, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=43, previous_yes_bid_dollars='0.4300', previous_yes_ask=44, previous_yes_ask_dollars='0.4400', previous_price=44, previous_price_dollars='0.4400', liquidity=159711424, liquidity_dollars='1597114.2400', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': 'ab9e2e9a-3243-41b6-a291-95f4d9c6edf7'}, rules_primary='If Sacramento wins the Miami at Sacramento professional basketball game originally scheduled for Jan 20, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNBAGAME-26JAN20MIASAC-MIA', event_ticker='KXNBAGAME-26JAN20MIASAC', market_type='binary', title='Miami at Sacramento Winner?', subtitle='', yes_sub_title='Miami', no_sub_title='Miami', created_time=datetime.datetime(2026, 1, 18, 14, 1, 58, 292396, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 18, 19, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 21, 6, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=99, yes_bid_dollars='0.9900', yes_ask=100, yes_ask_dollars='1.0000', no_bid=0, no_bid_dollars='0.0000', no_ask=1, no_ask_dollars='0.0100', last_price=99, last_price_dollars='0.9900', volume=1456437, volume_24h=1384728, result='', can_close_early=True, open_interest=975729, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=57, previous_yes_bid_dollars='0.5700', previous_yes_ask=58, previous_yes_ask_dollars='0.5800', previous_price=58, previous_price_dollars='0.5800', liquidity=161068565, liquidity_dollars='1610685.6500', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': 'a17e4a68-2999-4f60-b67e-3e80aa9e198b'}, rules_primary='If Miami wins the Miami at Sacramento professional basketball game originally scheduled for Jan 20, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNBAGAME-26JAN20TORGSW-TOR', event_ticker='KXNBAGAME-26JAN20TORGSW', market_type='binary', title='Toronto at Golden State Winner?', subtitle='', yes_sub_title='Toronto', no_sub_title='Toronto', created_time=datetime.datetime(2026, 1, 18, 14, 1, 57, 901336, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 18, 19, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 21, 6, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=95, yes_bid_dollars='0.9500', yes_ask=96, yes_ask_dollars='0.9600', no_bid=4, no_bid_dollars='0.0400', no_ask=5, no_ask_dollars='0.0500', last_price=96, last_price_dollars='0.9600', volume=2278347, volume_24h=2224201, result='', can_close_early=True, open_interest=1523929, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=40, previous_yes_bid_dollars='0.4000', previous_yes_ask=41, previous_yes_ask_dollars='0.4100', previous_price=41, previous_price_dollars='0.4100', liquidity=166128758, liquidity_dollars='1661287.5800', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '96c447dd-2cdd-4c58-a151-ef0df87de981'}, rules_primary='If Toronto wins the Toronto at Golden State professional basketball game originally scheduled for Jan 20, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNBAGAME-26JAN20TORGSW-GSW', event_ticker='KXNBAGAME-26JAN20TORGSW', market_type='binary', title='Toronto at Golden State Winner?', subtitle='', yes_sub_title='Golden State', no_sub_title='Golden State', created_time=datetime.datetime(2026, 1, 18, 14, 1, 57, 901336, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 18, 19, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 21, 6, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=4, yes_bid_dollars='0.0400', yes_ask=6, yes_ask_dollars='0.0600', no_bid=94, no_bid_dollars='0.9400', no_ask=96, no_ask_dollars='0.9600', last_price=6, last_price_dollars='0.0600', volume=2879504, volume_24h=2799762, result='', can_close_early=True, open_interest=1974529, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=59, previous_yes_bid_dollars='0.5900', previous_yes_ask=60, previous_yes_ask_dollars='0.6000', previous_price=60, previous_price_dollars='0.6000', liquidity=162704771, liquidity_dollars='1627047.7100', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '502c629b-4da7-40fd-92ab-20cb55411c35'}, rules_primary='If Golden State wins the Toronto at Golden State professional basketball game originally scheduled for Jan 20, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNBAGAME-26JAN20LALDEN-LAL', event_ticker='KXNBAGAME-26JAN20LALDEN', market_type='binary', title='Los Angeles L at Denver Winner?', subtitle='', yes_sub_title='Los Angeles L', no_sub_title='Los Angeles L', created_time=datetime.datetime(2026, 1, 18, 14, 1, 57, 609470, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 18, 19, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 21, 6, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=74, yes_bid_dollars='0.7400', yes_ask=75, yes_ask_dollars='0.7500', no_bid=25, no_bid_dollars='0.2500', no_ask=26, no_ask_dollars='0.2600', last_price=74, last_price_dollars='0.7400', volume=5925683, volume_24h=5796943, result='', can_close_early=True, open_interest=3924371, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=56, previous_yes_bid_dollars='0.5600', previous_yes_ask=58, previous_yes_ask_dollars='0.5800', previous_price=58, previous_price_dollars='0.5800', liquidity=322338714, liquidity_dollars='3223387.1400', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': '2ef4d31c-0b46-4f43-a403-f44d62489034'}, rules_primary='If Los Angeles L wins the Los Angeles L at Denver professional basketball game originally scheduled for Jan 20, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNBAGAME-26JAN20LALDEN-DEN', event_ticker='KXNBAGAME-26JAN20LALDEN', market_type='binary', title='Los Angeles L at Denver Winner?', subtitle='', yes_sub_title='Denver', no_sub_title='Denver', created_time=datetime.datetime(2026, 1, 18, 14, 1, 57, 609470, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 18, 19, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 21, 6, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 4, 3, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=25, yes_bid_dollars='0.2500', yes_ask=26, yes_ask_dollars='0.2600', no_bid=74, no_bid_dollars='0.7400', no_ask=75, no_ask_dollars='0.7500', last_price=25, last_price_dollars='0.2500', volume=4237937, volume_24h=4087028, result='', can_close_early=True, open_interest=2711898, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=42, previous_yes_bid_dollars='0.4200', previous_yes_ask=44, previous_yes_ask_dollars='0.4400', previous_price=44, previous_price_dollars='0.4400', liquidity=319879276, liquidity_dollars='3198792.7600', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'basketball_team': 'ba2cb6be-9827-46a8-8e6f-d8661307ba77'}, rules_primary='If Denver wins the Los Angeles L at Denver professional basketball game originally scheduled for Jan 20, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]))]

# %%
import time
import threading
from datetime import datetime
from collections import deque
import uuid
import os
import logging

# ---------- Market Maker Bot with Stop/Take Limits ----------

class MarketMakerBot:
    def __init__(
        self,
        client,
        market,
        side: str = "yes",           # "yes" or "no"
        spread_bps: int = 50,        # spread in basis points (0.0050 = 50 bps)
        size_per_level: int = 1,     # contracts per level
        max_position: int = 10,      # max inventory (+ or -)
        stop_loss: float = -10.0,    # stop if P&L <= this ($)
        take_profit: float = 20.0,   # stop if P&L >= this ($)
        skew_on_inventory: bool = True,  # skew quotes based on inventory
        skew_bps_per_contract: int = 10, # how much to skew per contract
        check_interval_s: float = 2.0,   # how often to update quotes
        logger: logging.Logger = None,
    ):
        self.client = client
        self.market = market
        self.ticker = market.model_dump()['ticker']
        self.side = side
        self.spread_bps = spread_bps / 10000.0  # convert to decimal
        self.size_per_level = size_per_level
        self.max_position = max_position
        self.stop_loss = stop_loss
        self.take_profit = take_profit
        self.skew_on_inventory = skew_on_inventory
        self.skew_bps_per_contract = skew_bps_per_contract / 10000.0
        self.check_interval_s = check_interval_s
        
        # Logging setup
        if logger is None:
            log_dir = "logs"
            os.makedirs(log_dir, exist_ok=True)
            session_id = str(uuid.uuid4())[:8]
            date_str = datetime.now().strftime("%Y-%m-%d")
            log_filename = f"mm_{date_str}_{session_id}.log"
            log_path = os.path.join(log_dir, log_filename)
            
            self.logger = logging.getLogger(f"mm_{session_id}")
            self.logger.setLevel(logging.DEBUG)
            self.logger.handlers = []
            
            fh = logging.FileHandler(log_path)
            fh.setLevel(logging.DEBUG)
            fh.setFormatter(logging.Formatter('%(asctime)s | %(levelname)s | %(message)s'))
            self.logger.addHandler(fh)
            
            ch = logging.StreamHandler()
            ch.setLevel(logging.INFO)
            ch.setFormatter(logging.Formatter('%(message)s'))
            self.logger.addHandler(ch)
            
            self.logger.info(f"=== Market Maker Bot started: {log_path} ===")
        else:
            self.logger = logger
        
        # State tracking
        self.position = 0           # current inventory (net contracts)
        self.realized_pnl = 0.0     # locked in P&L
        self.avg_entry_price = 0.0  # average price of current position
        self.total_filled = 0       # total contracts traded
        self.trade_history = []
        self.active_orders = {}     # order_id -> order_info
        
        self.stop_evt = threading.Event()
        self.running = False
        self.thread = None
        
        self.logger.info(f"MarketMakerBot initialized:")
        self.logger.info(f"  Ticker: {self.ticker}, Side: {side}")
        self.logger.info(f"  Spread: {spread_bps} bps, Size: {size_per_level}")
        self.logger.info(f"  Max Position: ±{max_position}")
        self.logger.info(f"  Stop Loss: ${stop_loss}, Take Profit: ${take_profit}")
        self.logger.info(f"  Skew on inventory: {skew_on_inventory}")
    
    def start(self):
        """Start the market making bot"""
        if self.running:
            self.logger.warning("Bot already running")
            return self
        
        self.running = True
        self.stop_evt.clear()
        self.thread = threading.Thread(target=self._run, daemon=True)
        self.thread.start()
        self.logger.info("✓ Market maker bot started")
        return self
    
    def stop(self):
        """Stop the bot and cancel all orders"""
        if not self.running:
            return
        
        self.logger.info("Stopping market maker bot...")
        self.stop_evt.set()
        self._cancel_all_orders()
        
        if self.thread:
            self.thread.join(timeout=5.0)
        
        self.running = False
        self.logger.info("✓ Market maker bot stopped")
        self._print_summary()
    
    def _get_mid_price(self):
        """Get current mid price of the market"""
        try:
            # Refresh market data
            market_response = self.client.get_market(self.ticker)
            data = market_response.market.model_dump()
            
            # Helper to safely convert to float
            def safe_float(val, default=0.0):
                if val is None:
                    return default
                try:
                    return float(val)
                except (ValueError, TypeError):
                    return default
            
            if self.side == "yes":
                bid = safe_float(data.get("yes_bid_dollars"), 0.0)
                ask = safe_float(data.get("yes_ask_dollars"), 1.0)
            else:
                bid = safe_float(data.get("no_bid_dollars"), 0.0)
                ask = safe_float(data.get("no_ask_dollars"), 1.0)
            
            if bid > 0 and ask > 0 and ask > bid:
                mid = (bid + ask) / 2.0
            else:
                # Fallback to last price or 0.5
                mid = 0.5
            
            return mid, bid, ask
        except Exception as e:
            self.logger.error(f"Error getting mid price: {e}")
            return 0.5, 0.0, 1.0
    
    def _calculate_quotes(self):
        """Calculate bid/ask quotes based on mid price and inventory"""
        mid, market_bid, market_ask = self._get_mid_price()
        
        # Base quotes: mid ± spread/2
        base_bid = mid - self.spread_bps / 2.0
        base_ask = mid + self.spread_bps / 2.0
        
        # Apply inventory skew if enabled
        if self.skew_on_inventory and self.position != 0:
            # If long (positive position), lower both quotes to encourage selling
            # If short (negative position), raise both quotes to encourage buying
            skew = self.position * self.skew_bps_per_contract
            base_bid -= skew
            base_ask -= skew
        
        # Clamp to valid range [0.01, 0.99]
        bid = max(0.01, min(0.99, base_bid))
        ask = max(0.01, min(0.99, base_ask))
        
        # Ensure ask > bid
        if ask <= bid:
            mid_point = (bid + ask) / 2.0
            bid = mid_point - 0.005
            ask = mid_point + 0.005
        
        return bid, ask, mid
    
    def _should_quote(self):
        """Check if we should place quotes given current position"""
        # Don't buy if at max long position
        can_buy = self.position < self.max_position
        # Don't sell if at max short position
        can_sell = self.position > -self.max_position
        
        return can_buy, can_sell
    
    def _place_order(self, action: str, price: float, quantity: int):
        """Place a limit order"""
        try:
            price_cents = int(round(price * 100))
            
            # Ensure price is within valid range (1-99 cents)
            price_cents = max(1, min(99, price_cents))
            
            order_params = {
                "ticker": self.ticker,
                "action": action,
                "side": self.side,
                "count": quantity,
                "type": "limit",
            }
            
            if self.side == "yes":
                order_params["yes_price"] = price_cents
            else:
                order_params["no_price"] = price_cents
            
            self.logger.debug(f"Order params: {order_params}")
            
            response = self.client.create_order(**order_params)
            order_id = response.order.order_id if hasattr(response, 'order') else None
            
            if order_id:
                self.active_orders[order_id] = {
                    "action": action,
                    "price": price,
                    "quantity": quantity,
                    "time": time.time()
                }
                self.logger.debug(f"Placed {action} order: {quantity} @ ${price:.3f} (id={order_id})")
            
            return order_id
        except Exception as e:
            self.logger.error(f"Error placing {action} order: {e}")
            return None
    
    def _cancel_all_orders(self):
        """Cancel all active orders"""
        if not self.active_orders:
            return
        self.logger.info(f"Canceling {len(self.active_orders)} active orders...")
        
        
        for order_id in list(self.active_orders.keys()):
            try:
                self.client.cancel_order(order_id=order_id)
                self.logger.debug(f"Canceled order {order_id}")
            except Exception as e:
                self.logger.debug(f"Error canceling order {order_id}: {e}")
        
        self.active_orders.clear()
    
    def _check_fills(self):
        """Check for filled orders and update position"""
        if not self.active_orders:
            return
        
        for order_id in list(self.active_orders.keys()):
            try:
                response = self.client.get_order(order_id=order_id)
                status = response.order.status if hasattr(response, 'order') else None
                
                if status == "filled":
                    order_info = self.active_orders[order_id]
                    self._handle_fill(order_info)
                    del self.active_orders[order_id]
                elif status in ["canceled", "expired"]:
                    del self.active_orders[order_id]
            except Exception as e:
                self.logger.debug(f"Error checking order {order_id}: {e}")
    
    def _handle_fill(self, order_info):
        """Handle a filled order and update P&L"""
        action = order_info["action"]
        price = order_info["price"]
        quantity = order_info["quantity"]
        
        # Update position
        if action == "buy":
            # Buying increases position
            new_position = self.position + quantity
            
            # Update average entry price
            if self.position >= 0:
                # Adding to long or flipping from flat
                total_cost = self.position * self.avg_entry_price + quantity * price
                self.avg_entry_price = total_cost / new_position if new_position != 0 else price
            else:
                # Reducing short position - realize P&L
                contracts_covered = min(quantity, abs(self.position))
                pnl = contracts_covered * (self.avg_entry_price - price)
                self.realized_pnl += pnl
                
                remaining = quantity - contracts_covered
                if remaining > 0:
                    # Flipped to long
                    self.avg_entry_price = price
            self.position = new_position
            
            
        else:  # action == "sell"
            # Selling decreases position
            new_position = self.position - quantity
            
            # Update average entry price
            if self.position <= 0:
                # Adding to short or flipping from flat
                total_cost = abs(self.position) * self.avg_entry_price + quantity * price
                self.avg_entry_price = total_cost / abs(new_position) if new_position != 0 else price
            else:
                # Reducing long position - realize P&L
                contracts_sold = min(quantity, self.position)
                pnl = contracts_sold * (price - self.avg_entry_price)
                self.realized_pnl += pnl
                
                remaining = quantity - contracts_sold
                if remaining > 0:
                    # Flipped to short
                    self.avg_entry_price = price
            
            self.position = new_position
        
        self.total_filled += quantity
        self.trade_history.append({
            "time": time.time(),
            "action": action,
            "price": price,
            "quantity": quantity,
            "position_after": self.position
        })
        
        ts = datetime.now().strftime("%H:%M:%S")
        unrealized = self._calculate_unrealized_pnl()
        total_pnl = self.realized_pnl + unrealized
        
        msg = (f"[{ts}] FILL: {action.upper()} {quantity} @ ${price:.3f} | "
               f"Pos: {self.position:+d} | P&L: ${total_pnl:.2f} "
               f"(realized: ${self.realized_pnl:.2f}, unrealized: ${unrealized:.2f})")
        print(msg)
        self.logger.info(msg)
    
    def _calculate_unrealized_pnl(self):
        """Calculate unrealized P&L on current position"""
        if self.position == 0:
            return 0.0
        mid, _, _ = self._get_mid_price()
        
        
        if self.position > 0:
            # Long position: unrealized = position * (current_price - avg_entry)
            unrealized = self.position * (mid - self.avg_entry_price)
        else:
            # Short position: unrealized = abs(position) * (avg_entry - current_price)
            unrealized = abs(self.position) * (self.avg_entry_price - mid)
        
        return unrealized
    
    def get_total_pnl(self):
        """Get total P&L (realized + unrealized)"""
        return self.realized_pnl + self._calculate_unrealized_pnl()
    
    def _check_risk_limits(self):
        """Check if stop loss or take profit hit"""
        total_pnl = self.get_total_pnl()
        
        if total_pnl <= self.stop_loss:
            msg = f"⚠ STOP LOSS HIT: P&L ${total_pnl:.2f} <= ${self.stop_loss:.2f}"
            print(msg)
            self.logger.warning(msg)
            return True
        
        if total_pnl >= self.take_profit:
            msg = f"✓ TAKE PROFIT HIT: P&L ${total_pnl:.2f} >= ${self.take_profit:.2f}"
            print(msg)
            self.logger.info(msg)
            return True
        
        return False
    
    def _run(self):
        """Main market making loop"""
        while not self.stop_evt.is_set():
            try:
                # Check for fills first
                self._check_fills()
                
                # Check risk limits
                if self._check_risk_limits():
                    self.stop()
                    break
                
                # Cancel existing orders
                self._cancel_all_orders()
                
                # Calculate new quotes
                bid, ask, mid = self._calculate_quotes()
                can_buy, can_sell = self._should_quote()
                
                ts = datetime.now().strftime("%H:%M:%S")
                total_pnl = self.get_total_pnl()
                
                # Place new orders
                if can_buy:
                    self._place_order("buy", bid, self.size_per_level)
                
                if can_sell:
                    self._place_order("sell", ask, self.size_per_level)
                
                self.logger.debug(
                    f"[{ts}] Quotes: bid=${bid:.3f} ask=${ask:.3f} mid=${mid:.3f} | "
                    f"Pos: {self.position:+d}/{self.max_position} | P&L: ${total_pnl:.2f}"
                )
                
                # Wait before next update
                time.sleep(self.check_interval_s)
                
            except Exception as e:
                self.logger.error(f"Error in market maker loop: {e}", exc_info=True)
                time.sleep(self.check_interval_s)
    
    def _print_summary(self):
        """Print trading summary"""
        print("\n" + "="*60)
        print("MARKET MAKER SUMMARY")
        print("="*60)
        print(f"Ticker: {self.ticker} ({self.side})")
        print(f"Total Contracts Filled: {self.total_filled}")
        print(f"Final Position: {self.position:+d}")
        print(f"Realized P&L: ${self.realized_pnl:.2f}")
        print(f"Unrealized P&L: ${self._calculate_unrealized_pnl():.2f}")
        print(f"Total P&L: ${self.get_total_pnl():.2f}")
        print("="*60 + "\n")

# pairs = kalshi_wrapped.GetMarketPairs(college_markets)
# Usage example:
# pairs = kalshi_wrapped.GetMarketPairs(college_markets)
# selected_market = pairs[0][0]  # Select a market from pairs
# 
# bot = MarketMakerBot(
#     client=kalshi_wrapped.GetClient(),
#     market=selected_market,     # Pass the market object
#     side="yes",
#     spread_bps=50,          # 0.5% spread
#     size_per_level=1,       # 1 contract per level
#     max_position=10,        # max ±10 contracts
#     stop_loss=-10.0,        # stop if lose $10
#     take_profit=20.0,       # stop if profit $20
#     skew_on_inventory=True, # skew quotes based on position
#     skew_bps_per_contract=10,  # 0.1% skew per contract
#     check_interval_s=2.0,   # update every 2 seconds
# ).start()
#
# To check status:
# print(f"Position: {bot.position}, P&L: ${bot.get_total_pnl():.2f}")
# To stop:
# bot.stop()
# To stop:# bot.stop()

# To stop:

# %% [markdown]
# ## Market Maker Bot Configuration
#
# Select a market and configure the bot parameters below:
#
# **Key Parameters:**
# - `spread_bps`: Spread in basis points (50 bps = 0.5% = $0.005)
# - `size_per_level`: Number of contracts to quote on each side
# - `max_position`: Maximum inventory (±contracts). Bot won't buy if at +max, won't sell if at -max
# - `stop_loss`: Stop trading if P&L drops to this level (in dollars)
# - `take_profit`: Stop trading if P&L reaches this level (in dollars)
# - `skew_on_inventory`: If True, skew quotes when inventory builds up
#   - Long inventory → lower quotes to encourage selling
#   - Short inventory → raise quotes to encourage buying
# - `skew_bps_per_contract`: How much to adjust quotes per contract of inventory
# - `check_interval_s`: How often to update quotes (seconds)

# %%
# Step 1: Select a market from the available pairs
# Example: Use the first college basketball market pair
if college_markets:
    pairs = kalshi_wrapped.GetMarketPairs(college_markets)
    if pairs:
        # Show first 3 pairs
        print("Available market pairs:")
        for i, pair in enumerate(pairs[:3]):
            m1, m2 = pair
            print(f"\n{i+1}. {m1.model_dump()['ticker']}")
            print(f"   {m1.model_dump()['title']}")
            print(f"   {m2.model_dump()['ticker']}")
            print(f"   {m2.model_dump()['title']}")
        
        # Select the first market's first side
        selected_market = pairs[0][0]
        print(f"\n✓ Selected market: {selected_market.model_dump()['ticker']}")
        print(f"   Title: {selected_market.model_dump()['title']}")
else:
    print("No college markets available. Try NBA or NHL markets.")
# Out:
# Available market pairs:
#
# 1. KXNCAAMBGAME-26JAN23CSBHAW-HAW
#    Cal State Bakersfield at Hawai'i Winner?
#    KXNCAAMBGAME-26JAN23CSBHAW-CSB
#    Cal State Bakersfield at Hawai'i Winner?
#
# 2. KXNCAAMBGAME-26JAN22UCIUCRV-UCRV
#    UC Irvine at UC Riverside Winner?
#    KXNCAAMBGAME-26JAN22UCIUCRV-UCI
#    UC Irvine at UC Riverside Winner?
#
# 3. KXNCAAMBGAME-26JAN22LBSUCSF-LBSU
#    Long Beach St. at Cal State Fullerton Winner?
#    KXNCAAMBGAME-26JAN22LBSUCSF-CSF
#    Long Beach St. at Cal State Fullerton Winner?
#
# ✓ Selected market: KXNCAAMBGAME-26JAN23CSBHAW-HAW
#    Title: Cal State Bakersfield at Hawai'i Winner?

# %%
# Manual market selection (if needed)
# Find a specific market from the available markets
event_name = "kxncaambgame-26jan20unlvusu".upper()
selected_market = kalshi_wrapped.GetMarketByTicker(college_markets, event_name)
print(f"Selected: {selected_market.model_dump()['ticker']}")
# Out:
# Selected: KXNBAGAME-26JAN20LALDEN-LAL

# %%
# Verify the selected market is valid and open
try:
    ticker = selected_market.model_dump()['ticker']
    status = selected_market.model_dump().get('status', 'unknown')
    title = selected_market.model_dump().get('title', 'N/A')
    
    print(f"✓ Selected Market:")
    print(f"  Ticker: {ticker}")
    print(f"  Title: {title}")
    print(f"  Status: {status}")
    
    # Try to get fresh market data
    market_check = kalshi_wrapped.GetClient().get_market(ticker)
    data = market_check.market.model_dump()
    
    # Handle string or numeric values
    def safe_float(val):
        if val is None:
            return 0.0
        try:
            return float(val)
        except (ValueError, TypeError):
            return 0.0
    
    yes_bid = safe_float(data.get('yes_bid_dollars', 0))
    yes_ask = safe_float(data.get('yes_ask_dollars', 1))
    no_bid = safe_float(data.get('no_bid_dollars', 0))
    no_ask = safe_float(data.get('no_ask_dollars', 1))
    
    print(f"\n✓ Market is accessible")
    print(f"  YES bid/ask: ${yes_bid:.3f} / ${yes_ask:.3f}")
    print(f"  NO bid/ask: ${no_bid:.3f} / ${no_ask:.3f}")
    
    if status != 'open' and status != 'active':
        print(f"\n⚠ WARNING: Market status is '{status}' - may not be tradeable")
except Exception as e:
    print(f"✗ ERROR: Cannot access market: {e}")
    print(f"  The market may be closed, settled, or invalid.")
    print(f"  Please select a different market with status='open'")
# Out:
# ✓ Selected Market:
#   Ticker: KXNBAGAME-26JAN20LALDEN-LAL
#   Title: Los Angeles L at Denver Winner?
#   Status: active
#
# ✓ Market is accessible
#   YES bid/ask: $0.770 / $0.780
#   NO bid/ask: $0.220 / $0.230

# %%
# Step 2: Create and start the market maker bot
bot = MarketMakerBot(
    client=kalshi_wrapped.GetClient(),
    market=selected_market,       # Pass the market object
    side="yes",                   # "yes" or "no"
    spread_bps=50,                # 0.5% spread (50 basis points)
    size_per_level=100,           # 1 contract per level
    max_position=5,               # max ±5 contracts inventory
    stop_loss=-5.0,               # stop if P&L drops to -$5
    take_profit=10.0,             # stop if P&L reaches +$10
    skew_on_inventory=True,       # adjust quotes based on inventory
    skew_bps_per_contract=10,     # 0.1% adjustment per contract
    check_interval_s=3.0,         # update quotes every 3 seconds
).start()

print(f"\n✓ Market maker bot started on {bot.ticker}")
print(f"  Monitoring P&L. Will stop if P&L <= -$5 or >= +$10")
print(f"  Run bot.stop() to manually stop the bot")
# Out:
# === Market Maker Bot started: logs/mm_2026-01-20_428bae36.log ===
# MarketMakerBot initialized:
#   Ticker: KXNBAGAME-26JAN20LALDEN-LAL, Side: yes
#   Spread: 50 bps, Size: 100
#   Max Position: ±5
#   Stop Loss: $-5.0, Take Profit: $10.0
#   Skew on inventory: True
# ✓ Market maker bot started
# ✓ Market maker bot started on KXNBAGAME-26JAN20LALDEN-LAL
#   Monitoring P&L. Will stop if P&L <= -$5 or >= +$10
#   Run bot.stop() to manually stop the bot
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 1 active orders...
# Canceling 2 active orders...
# Canceling 1 active orders...
# Canceling 1 active orders...
# Canceling 1 active orders...
# Canceling 1 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 1 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 1 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 1 active orders...
# Canceling 1 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 1 active orders...
# Canceling 1 active orders...
# Canceling 1 active orders...
# Canceling 1 active orders...
# Canceling 1 active orders...
# Canceling 1 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 1 active orders...
# Canceling 1 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...

# %%
bot.stop()
# Out:
# Stopping market maker bot...
# Canceling 2 active orders...
# Canceling 2 active orders...
# ✓ Market maker bot stopped
# ============================================================
# MARKET MAKER SUMMARY
# ============================================================
# Ticker: KXNBAGAME-26JAN20LALDEN-LAL (yes)
# Total Contracts Filled: 0
# Final Position: +0
# Realized P&L: $0.00
# Unrealized P&L: $0.00
# Total P&L: $0.00
# ============================================================
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 2 active orders...
# Canceling 1 active orders...
# Canceling 1 active orders...
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:21 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'eLtx1vFbvlmmC86iCIf9BC8oOa6Aminvd1NQt-_q0EK3mlSp8YPAaQ=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:21 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '_9XsLP0n1FYJhlomOhocK8-t2Zm7a9Y_ZxF2RO8xMgfDo2av7brGCA=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:21 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'ZtlVH-QhzRA2ObceU5YrAOnTdsCru3eUhEVJ5OZAYE_FeUx9Q4SQuA=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:21 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'pR9nICQ94ZhMvunp0yu29d6IznodFtt2eGBFH_soEnaTaaggEaIjxQ=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:24 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'z3nHw76U0d5NutbSaM38_uv7WDZhbxWl2SDSJyxcNhEWhu8iUVkUfw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:24 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '2VVJ5urIWwzsFSBVRhpnc8zaGZIyN3dUDKxzh44dxBLdy6V20-jiYA=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:24 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'kkCR8VQrbMeRyA13i2XjK48QIx1wJOdwuybzG_Qg5zOka-Bi9FSBpg=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:24 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'W-gJFASS0jo-eiUoxFUegtatKhaDflRLMnPGQpP6QDif4QNEiD1Zsw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:27 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'lzPwqL0m-7Oq7xTvevO3v5P1EitxjFJgZWWcwumwfGsdlkXSK0NGkw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:27 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '_n4A3r15dXAU6Hqu_SmUKBray4-Ce9yHdyMSfcNZLqw8zwhLFv_dGg=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:28 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'nG3CQu0ZdgyG29IabtT0kkBf144Ttb9ZB1bdKNse1EauxFcyJd36VQ=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:28 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'dTsUsqOn6YhhJfm1BU8OiJPL3L0NmGtlfQsAStScKfj6e5ijWC2F3Q=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:31 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'zObpJmtBO-Fba53P8_1k_bTa73H2nOiv99GLotHV_3EcLY8EFtKJvA=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:31 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '88F2uMhYz0dfsEfR8qPdl6V4TWYV5POzf2mp4pF5Z_v1puGJ-SihjA=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:31 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'CYEGOkJeR388jwrzHH69FyRPtMBWpGqqZOBMf0NYp67DD4P7Bc3law=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:31 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '5JZex1PB-MFzwTI8dUPB_91v0ZMjflo14yQMNSFyqFe-VLHzs7-huw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:34 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'fFpZlCYff9tD1FpRiAfVWkTEjGtj8g7o1v3ccgKfZFbZa27TYaVv5g=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:34 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'Psybi5c-FYj2yVuvPDQgNg-JZI2Z6z3bBinb4e-InBi30Zre6MXgSg=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:34 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'Mgvv32VzOXBXdtt1Ca9wSCT1sFZt6at0byRfh1Ju3sSRffEP9WS21w=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:34 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'eE79oRyshjAffNinEh45ckrSLIg2pHUm16lh6RhD8nddqbsrulNsCw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:37 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'KR1VVyZRMCKHRjz6m5kvkplr-FPGNIr8YArZBLz086-DLgOiDGJPlA=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:37 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'ZTrdROlDP9w9lhpW4l9gMaCtmyP5zpkjjfUtFpoZQDo6AGqk_gttcQ=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:37 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'sHcd2rHblb2fU_0VCVsFP2-HNhf35UTUD1sJPoS_Zi7m-wRf20beNw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:37 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'Qu_r7nXBXkqsz9lwFL4bwpTozGtuuqvQZ1LVh4BlSoZ5EXTpkuuBnw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:40 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'JJCZUqUgcVZ97vcaIZCMjS50cQkWGt02WsIBfr3RjeulH7fXPVtaNA=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:40 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'Z8dS3o441nWJYWni0TrXaNZdhScRKU3pSpHp62FhFPsEsBMmXrjpWQ=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:40 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'pOw66iRlxOpPJ4mBObSuAyf8ymOGDH1mdQRHT2IoX8Pe-cwY0CI_TQ=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:40 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'Mn4W0xDpnaYUKOkZsCQJ7_RTJbHTpKXZEgfEe51Q6q8brh0zd7FyAQ=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:44 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'RoirEtl4vYIeEifKZKJ17Qcy1MyO0VRbQ4mnqIojz38-fagrk7cOGw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:44 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'WiOeu4xIEJys-ddo7P8NeakKapMN-i_s6NSVTNJpe9xFRjorj5mXqQ=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:44 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'jvUT3iG3w4baoBFNHYjKwewo-f_bpx1U0UBK_2j6eT_L29nV595FSQ=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:44 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '_bYYdR_BP7aYj4CeRj3rT7N99ib8NBN3xRepQ7R0VQNUdaZ0kCVg6Q=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:47 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'nXfojN1X_YJTHfFuW6SjLK9j9F0Qs5uoQsuO4vV5or6p7xej1VAXgw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:47 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'Wn5VLmu9TbGd0p17xtvapPpm4YOvYXCTtHMMmipgTPAI9P28bFeqjA=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:47 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '0zlBXCUJeSkJ8gSj435JO-2lD8Xqf3_tvJf48JNYRJ0xtswKaNzZIw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:47 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'Da1Pos5ugmRLLhNkXuVfinnszapqVG5kxenGo4M3AdJcG8d6vSsfvw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:50 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'TPWZYLB6ZY04sQXdvamC_POd1kyfwxuXsEfCApT9K3g8VPkgjzE1Lg=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:50 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'HbH9ssk11lvjq2BvYCIhlDj2F-cH3MyaMRX2Y9onFHZB7bsW8tq68Q=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:50 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'IHhKJ7WbcYPcCYvyHcHPMM6rrTeYepdQGy-CRM9alb7Ut_p1ZAO7Aw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:50 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'dyCE9CGL2SIMgMaUadI_Czjm5yVzJBejBIGjbrWzyMMvU0rnKoI6iw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:53 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'piyze-ndZg6_i7twjIzUeKH9ftoDzU2RXb9NHgAuBr7N1_pLSRfOog=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:53 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '10C0ITaH4DuLDyzQtHASvOAHC_f9FTMfEtXStYHY5qsN8TNLqLLniA=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:53 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'MZGUQCSVOtzu-BzCVwZOLlXJZBW4GDl4I4aHSfBKLdkmLUvkR7iQfw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:53 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'zxVRY69KddUitJaUO7xP2gUSbTnsFGRvbwlziXhdvVLxj1CLvwycow=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:56 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'gGgrlymmqPzu-qzWIiENpM3TgzI68RXcDBD_eUC5VArZ-exPytkHVg=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:57 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '7ckRAmRtIY9fNRjjDDjJT6Hlz-pbKcg5wlfHEzYBIoR1W_hMRKla_A=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:57 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '6zwGYHxM5M6NTbZR4H7gOfZzL6wXW1d4Sf6V1YUbkqOUf052ft28eg=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:36:57 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '1Q2RT8nStIqnCVm9DlnlHn3E4piJXK6MdVICB93GQ6s7BdkEE-vMSw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:37:00 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'RGPXVrZEk27JYEBFvXceqtbkh8H85vag7I87u1uEeWZJ2owjNiWsVg=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:37:00 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'mTdCNvff509bLTGk220WTSc_02RzjkQcUGoElaqeJodpAgXgBtA3Lw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:37:00 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'zkP_5LtguwmEy1HC2wQJ8yVEMYl2WkRbHcWIKpwAGD-wpaveu3edFg=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:37:00 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'a__8D96EPCly2YABhdmQZEjgCvYtQu2jOWER-uLnc34p3iTSk-sOHQ=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:37:03 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'cocq-ktdii6kpgdsc-RBJ3GLtgaC58AsUTHF08C5F3zGkxOKjTG8fw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:37:03 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'c6YFqGFh2w0Grw04Qv6UyzaGiBmwjGCPo1A6vkhMFL8QUgHTFL2Dzw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:37:03 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '2oUVQaucBQYZPrWTvXfgKpqJisrl1C4OeGoxKfOPliZ7gZCIfrIKzA=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:37:03 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'KlvpUhQHHpcNdGl8F9NBdZhGBqmETe86T5ZHM8m92Toi6m6PmQMtGA=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:37:06 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'NbapRX9WKaxRio2xr0XuPGreaQket_y7GqiezeSwazbrYi3nwgdejQ=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:37:06 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 1b3830d707f4ac60e56d5750ec483784.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'T7pDmd3it-57yz2O25wBwStVUG_Kv0F9JSnlxo8wYpaSHIrMxwmSkA=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:37:06 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'm5ShJqB3cOBa6vTdB2U86N0DWY4R3O0L5BEfjfCjfW7JpMMXAP44Hw=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:37:06 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'aaMRLmrsL-xbmhwhfLEWvUthmOql-DBR_4-oage5Xjtk8FqoxWMgDA=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:37:09 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'zyXdiSA9_DPzZDAfNj8IxfrsJ5s0Vv6QdSPg0KeNLJH-m2q1jmj8eA=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing sell order: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '89', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 05:37:09 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '-GmFkCCeBltFTmEAV97WK0diaaA19Wj9kdeSraG3qpJELfBmAY-jaA=='})
# HTTP response body: code=None message=None details=None service=None
#
# Error placing buy order: (409)
# Reason: Conflict
# ...
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing buy order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:14 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '-oedpmWzCPicc5O3ct303CDvxen-7j20bxGfPUXKSKnYG8OwYT9--w=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing sell order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:14 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'WALqE-v1Zp6K5oZQ4f32B4dQwMLlZsJzglqJ1lIvjkfK7ZwzvWLDvg=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing buy order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:15 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '1-m1MvXZouCHuqL3B-nQp_oIeAaFFa4udC-VicVb72lZsSnUIcWRQQ=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing sell order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:15 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'CWzEfApIwQ16_1tRD_8W109xVIB7cuoidW-96jZPwH4FwbAXPKq8cA=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing buy order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:17 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'V1ZszSguMVEGONVAD07CHBdFyOLbHLwBO0ZFcwGFkwE7tNtPoEO0Nw=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing sell order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:17 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'PQTaGJ9apr7F9scXge5iS5xWDRhQNEr40tb0Tdx0YlmiKRquWeLa1A=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing buy order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:18 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'Bpd9C6-WmG_jNEwupxyjnZkmv2ZI1JtJ5KHs3FGn14S8_eTbBHQXpg=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing sell order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:19 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'Quy8Me3aZTcr7ECbwvYrl64Dw_DyhFgT3qG2WCV1rmf512TpWuuWDA=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing buy order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:20 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'PB3hmgXsuoXiKvn8kbRntXlGRIyZuY4kuclSAc_cmgmAgjCRsPqy_w=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing sell order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:20 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'NzjBWzdVIXVDrHgTWMiJnImbvkDgQn4JbEH-rhoHwrO4ZW8RoR9KeQ=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing buy order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:22 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'd8vIPxWPhvOTjPHSTE4ySFuGPqkh_TWN1oPx2bjjchwje3K58k2IYg=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing sell order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:22 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'DfR7hQG8jtVgkbPw1ELHCPMVKt7XizLrvFbMG0uMummR3Mmo6hGUZQ=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing buy order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:24 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'M5ldeIgMkNEXO1LzQT4yC4aMflQP-rRhVhfnGYDHqzSxZphkt9Qkbw=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing sell order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:24 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'gv1vZeYO-Z6_AwhMXwPIM9R5dAgtu034GELufBk-rJ-qCS2fVtb9BQ=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing buy order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:25 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'fB2WyWcft0cbi_TyEJ3gg37lTYMAnu9CqJsISuwan0zSOnrR9X0s3Q=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing sell order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:25 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'Rr1MtR0-y6UmCzpK83RVxjKlcPq2MyQ0k4KxtzLOSae2p3bQuRYtiw=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing buy order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:27 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'orIA7b1JIRBdV0ZxMtiQ7rZ88kkHt7wkPQbO2eyk-QpLUKEBISMjgQ=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing sell order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:27 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'eJxhUyFAw_GqtkJpVUWYcNeAKQESDkx4BMayJhtW6DTA-mdRRhEXsg=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing buy order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:28 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '4eUVbs6QUsniG4rTZcUCWpQExCMiQiHke99keegK7khdvr41rmYk-w=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing sell order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:28 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'pcVqd9MH10Ge3W3ZaPMnP1rGhIs5bcYujBmK0UIBLVEhZ-PjLVD6SQ=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing buy order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:30 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': 'j5sUT7whw4qk9fFvZRro-UvNH4CBnx0e_QLgdhq1GxWP17PouanPjQ=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}
#
# Error placing sell order: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '87', 'Connection': 'keep-alive', 'Date': 'Wed, 21 Jan 2026 06:20:30 GMT', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none';", 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'X-Cache': 'Error from cloudfront', 'Via': '1.1 3df18539d06c808feb25fa5eef14663c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'SFO53-P10', 'X-Amz-Cf-Id': '6IIrW7avhH54uxmzA3tThZd4niLynEYsso-q3QD1j6XnQqaHBbi5bA=='})
# HTTP response body: {"error":{"code":"market_not_found","message":"market not found","service":"exchange"}}

# %%
# Step 3: Monitor the bot status
print(f"Position: {bot.position:+d} contracts")
print(f"Realized P&L: ${bot.realized_pnl:.2f}")
print(f"Unrealized P&L: ${bot._calculate_unrealized_pnl():.2f}")
print(f"Total P&L: ${bot.get_total_pnl():.2f}")
print(f"Total Filled: {bot.total_filled} contracts")
print(f"Active Orders: {len(bot.active_orders)}")

# %%
# Step 4: View trade history
if bot.trade_history:
    import pandas as pd
    df = pd.DataFrame(bot.trade_history)
    df['time'] = pd.to_datetime(df['time'], unit='s')
    print("\nTrade History:")
    print(df.to_string(index=False))
else:
    print("No trades executed yet")

# %%
# Step 5: Stop the bot manually (if needed)
bot.stop()
# The bot will automatically stop when stop_loss or take_profit is hit
