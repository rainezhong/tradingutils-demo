# %%
import sys
import os
# Add parent directory to path to import tradingutils modules
sys.path.insert(0, os.path.abspath('..'))

from kalshi_utils.client_wrapper import *

# %%
kalshi_wrapped = KalshiWrapped()
# Out:
# Client Created

# %%
nhl_live_markets = kalshi_wrapped.GetAllNHLMarkets(status="open")
soccer_markets = kalshi_wrapped.GetALLUCLMarkets(status="open")

# %%
kalshi_wrapped.GetMarketPairs(nhl_live_markets)
# Out:
# [(Market(ticker='KXNHLGAME-26JAN22DETMIN-MIN', event_ticker='KXNHLGAME-26JAN22DETMIN', market_type='binary', title='Detroit at Minnesota Winner?', subtitle='', yes_sub_title='MIN Wild', no_sub_title='MIN Wild', created_time=datetime.datetime(2026, 1, 20, 5, 1, 41, 907604, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 10, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 2, 30, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 5, 30, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 2, 30, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 2, 30, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=51, yes_bid_dollars='0.5100', yes_ask=57, yes_ask_dollars='0.5700', no_bid=43, no_bid_dollars='0.4300', no_ask=49, no_ask_dollars='0.4900', last_price=57, last_price_dollars='0.5700', volume=5, volume_24h=5, result='', can_close_early=True, open_interest=3, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=2212078, liquidity_dollars='22120.7800', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '1cee0410-99f1-43a2-a67c-4e6a3b968a9c'}, rules_primary='If MIN Wild wins the Detroit at Minnesota professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNHLGAME-26JAN22DETMIN-DET', event_ticker='KXNHLGAME-26JAN22DETMIN', market_type='binary', title='Detroit at Minnesota Winner?', subtitle='', yes_sub_title='DET Red Wings', no_sub_title='DET Red Wings', created_time=datetime.datetime(2026, 1, 20, 5, 1, 41, 907604, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 10, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 2, 30, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 5, 30, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 2, 30, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 2, 30, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=41, yes_bid_dollars='0.4100', yes_ask=46, yes_ask_dollars='0.4600', no_bid=54, no_bid_dollars='0.5400', no_ask=59, no_ask_dollars='0.5900', last_price=0, last_price_dollars='0.0000', volume=0, volume_24h=0, result='', can_close_early=True, open_interest=0, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=2229512, liquidity_dollars='22295.1200', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '2e166d0f-2ebf-4477-84d8-7702257b797f'}, rules_primary='If DET Red Wings wins the Detroit at Minnesota professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNHLGAME-26JAN22FLAWPG-WPG', event_ticker='KXNHLGAME-26JAN22FLAWPG', market_type='binary', title='Florida at Winnipeg Winner?', subtitle='', yes_sub_title='WPG Jets', no_sub_title='WPG Jets', created_time=datetime.datetime(2026, 1, 20, 2, 1, 46, 223149, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 4, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=42, yes_bid_dollars='0.4200', yes_ask=48, yes_ask_dollars='0.4800', no_bid=52, no_bid_dollars='0.5200', no_ask=58, no_ask_dollars='0.5800', last_price=50, last_price_dollars='0.5000', volume=21, volume_24h=21, result='', can_close_early=True, open_interest=20, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=2239036, liquidity_dollars='22390.3600', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '6f769f6d-161e-43d3-a586-db5451c5050e'}, rules_primary='If WPG Jets wins the Florida at Winnipeg professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNHLGAME-26JAN22FLAWPG-FLA', event_ticker='KXNHLGAME-26JAN22FLAWPG', market_type='binary', title='Florida at Winnipeg Winner?', subtitle='', yes_sub_title='FLA Panthers', no_sub_title='FLA Panthers', created_time=datetime.datetime(2026, 1, 20, 2, 1, 46, 223149, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 4, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=54, yes_bid_dollars='0.5400', yes_ask=55, yes_ask_dollars='0.5500', no_bid=45, no_bid_dollars='0.4500', no_ask=46, no_ask_dollars='0.4600', last_price=55, last_price_dollars='0.5500', volume=368, volume_24h=368, result='', can_close_early=True, open_interest=368, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=4998738, liquidity_dollars='49987.3800', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '49b28762-c1b6-4962-a0cb-f1578510cad8'}, rules_primary='If FLA Panthers wins the Florida at Winnipeg professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNHLGAME-26JAN22PITEDM-PIT', event_ticker='KXNHLGAME-26JAN22PITEDM', market_type='binary', title='Pittsburgh at Edmonton Winner?', subtitle='', yes_sub_title='PIT Penguins', no_sub_title='PIT Penguins', created_time=datetime.datetime(2026, 1, 20, 2, 1, 45, 802465, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 2, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 5, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 2, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 2, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=34, yes_bid_dollars='0.3400', yes_ask=40, yes_ask_dollars='0.4000', no_bid=60, no_bid_dollars='0.6000', no_ask=66, no_ask_dollars='0.6600', last_price=40, last_price_dollars='0.4000', volume=88, volume_24h=88, result='', can_close_early=True, open_interest=88, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=2271497, liquidity_dollars='22714.9700', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '1b5c6299-90f7-49c7-8617-264610d50488'}, rules_primary='If PIT Penguins wins the Pittsburgh at Edmonton professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNHLGAME-26JAN22PITEDM-EDM', event_ticker='KXNHLGAME-26JAN22PITEDM', market_type='binary', title='Pittsburgh at Edmonton Winner?', subtitle='', yes_sub_title='EDM Oilers', no_sub_title='EDM Oilers', created_time=datetime.datetime(2026, 1, 20, 2, 1, 45, 802465, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 2, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 5, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 2, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 2, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=58, yes_bid_dollars='0.5800', yes_ask=64, yes_ask_dollars='0.6400', no_bid=36, no_bid_dollars='0.3600', no_ask=42, no_ask_dollars='0.4200', last_price=63, last_price_dollars='0.6300', volume=42, volume_24h=42, result='', can_close_early=True, open_interest=41, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=2353523, liquidity_dollars='23535.2300', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': 'e8b67c82-f465-450d-aef9-c8414f2ae83a'}, rules_primary='If EDM Oilers wins the Pittsburgh at Edmonton professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNHLGAME-26JAN22BUFMTL-MTL', event_ticker='KXNHLGAME-26JAN22BUFMTL', market_type='binary', title='Buffalo at Montreal Winner?', subtitle='', yes_sub_title='MTL Canadiens', no_sub_title='MTL Canadiens', created_time=datetime.datetime(2026, 1, 20, 2, 1, 45, 772698, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=56, yes_bid_dollars='0.5600', yes_ask=57, yes_ask_dollars='0.5700', no_bid=43, no_bid_dollars='0.4300', no_ask=44, no_ask_dollars='0.4400', last_price=56, last_price_dollars='0.5600', volume=36, volume_24h=36, result='', can_close_early=True, open_interest=36, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=2227784, liquidity_dollars='22277.8400', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '687da65c-5858-40e7-a189-0f20cf2a5686'}, rules_primary='If MTL Canadiens wins the Buffalo at Montreal professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNHLGAME-26JAN22BUFMTL-BUF', event_ticker='KXNHLGAME-26JAN22BUFMTL', market_type='binary', title='Buffalo at Montreal Winner?', subtitle='', yes_sub_title='BUF Sabres', no_sub_title='BUF Sabres', created_time=datetime.datetime(2026, 1, 20, 2, 1, 45, 772698, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=40, yes_bid_dollars='0.4000', yes_ask=47, yes_ask_dollars='0.4700', no_bid=53, no_bid_dollars='0.5300', no_ask=60, no_ask_dollars='0.6000', last_price=47, last_price_dollars='0.4700', volume=110, volume_24h=110, result='', can_close_early=True, open_interest=110, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=2232790, liquidity_dollars='22327.9000', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '458b20ce-1c62-47d8-8fc4-6f752a2476e7'}, rules_primary='If BUF Sabres wins the Buffalo at Montreal professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNHLGAME-26JAN22VGKBOS-VGK', event_ticker='KXNHLGAME-26JAN22VGKBOS', market_type='binary', title='Vegas at Boston Winner?', subtitle='', yes_sub_title='VGK Golden Knights', no_sub_title='VGK Golden Knights', created_time=datetime.datetime(2026, 1, 20, 2, 1, 45, 520959, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=55, yes_bid_dollars='0.5500', yes_ask=57, yes_ask_dollars='0.5700', no_bid=43, no_bid_dollars='0.4300', no_ask=45, no_ask_dollars='0.4500', last_price=57, last_price_dollars='0.5700', volume=643, volume_24h=643, result='', can_close_early=True, open_interest=643, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=5033875, liquidity_dollars='50338.7500', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': 'd599b5cc-5e06-4679-9303-4d5dad7c4cce'}, rules_primary='If VGK Golden Knights wins the Vegas at Boston professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNHLGAME-26JAN22VGKBOS-BOS', event_ticker='KXNHLGAME-26JAN22VGKBOS', market_type='binary', title='Vegas at Boston Winner?', subtitle='', yes_sub_title='BOS Bruins', no_sub_title='BOS Bruins', created_time=datetime.datetime(2026, 1, 20, 2, 1, 45, 520959, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=41, yes_bid_dollars='0.4100', yes_ask=47, yes_ask_dollars='0.4700', no_bid=53, no_bid_dollars='0.5300', no_ask=59, no_ask_dollars='0.5900', last_price=47, last_price_dollars='0.4700', volume=1683, volume_24h=1683, result='', can_close_early=True, open_interest=1683, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=4897757, liquidity_dollars='48977.5700', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '4163474f-3470-4f0c-8a60-c998e3f93810'}, rules_primary='If BOS Bruins wins the Vegas at Boston professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNHLGAME-26JAN22OTTNSH-OTT', event_ticker='KXNHLGAME-26JAN22OTTNSH', market_type='binary', title='Ottawa at Nashville Winner?', subtitle='', yes_sub_title='OTT Senators', no_sub_title='OTT Senators', created_time=datetime.datetime(2026, 1, 20, 2, 1, 45, 387272, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 4, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=50, yes_bid_dollars='0.5000', yes_ask=55, yes_ask_dollars='0.5500', no_bid=45, no_bid_dollars='0.4500', no_ask=50, no_ask_dollars='0.5000', last_price=55, last_price_dollars='0.5500', volume=1, volume_24h=1, result='', can_close_early=True, open_interest=1, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=2307343, liquidity_dollars='23073.4300', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': 'a2478063-2ded-4657-923b-e59de696ad21'}, rules_primary='If OTT Senators wins the Ottawa at Nashville professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNHLGAME-26JAN22OTTNSH-NSH', event_ticker='KXNHLGAME-26JAN22OTTNSH', market_type='binary', title='Ottawa at Nashville Winner?', subtitle='', yes_sub_title='NSH Predators', no_sub_title='NSH Predators', created_time=datetime.datetime(2026, 1, 20, 2, 1, 45, 387272, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 4, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 1, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=42, yes_bid_dollars='0.4200', yes_ask=49, yes_ask_dollars='0.4900', no_bid=51, no_bid_dollars='0.5100', no_ask=58, no_ask_dollars='0.5800', last_price=0, last_price_dollars='0.0000', volume=0, volume_24h=0, result='', can_close_early=True, open_interest=0, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=2374069, liquidity_dollars='23740.6900', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': 'fcfd0b58-cc0a-448e-8f4b-6ddeab8f339f'}, rules_primary='If NSH Predators wins the Ottawa at Nashville professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNHLGAME-26JAN22DALCBJ-DAL', event_ticker='KXNHLGAME-26JAN22DALCBJ', market_type='binary', title='Dallas at Columbus Winner?', subtitle='', yes_sub_title='DAL Stars', no_sub_title='DAL Stars', created_time=datetime.datetime(2026, 1, 20, 2, 1, 43, 862072, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=53, yes_bid_dollars='0.5300', yes_ask=56, yes_ask_dollars='0.5600', no_bid=44, no_bid_dollars='0.4400', no_ask=47, no_ask_dollars='0.4700', last_price=56, last_price_dollars='0.5600', volume=447, volume_24h=447, result='', can_close_early=True, open_interest=447, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=5519800, liquidity_dollars='55198.0000', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '5cfee6b9-43ff-4dfa-8347-2b9de7ed51b6'}, rules_primary='If DAL Stars wins the Dallas at Columbus professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNHLGAME-26JAN22DALCBJ-CBJ', event_ticker='KXNHLGAME-26JAN22DALCBJ', market_type='binary', title='Dallas at Columbus Winner?', subtitle='', yes_sub_title='CBJ Blue Jackets', no_sub_title='CBJ Blue Jackets', created_time=datetime.datetime(2026, 1, 20, 2, 1, 43, 862072, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=44, yes_bid_dollars='0.4400', yes_ask=49, yes_ask_dollars='0.4900', no_bid=51, no_bid_dollars='0.5100', no_ask=56, no_ask_dollars='0.5600', last_price=49, last_price_dollars='0.4900', volume=76, volume_24h=76, result='', can_close_early=True, open_interest=75, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=5093996, liquidity_dollars='50939.9600', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '253e2161-4b9b-4580-88e7-a25b9f6cf8af'}, rules_primary='If CBJ Blue Jackets wins the Dallas at Columbus professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNHLGAME-26JAN22CHICAR-CHI', event_ticker='KXNHLGAME-26JAN22CHICAR', market_type='binary', title='Chicago at Carolina Winner?', subtitle='', yes_sub_title='CHI Blackhawks', no_sub_title='CHI Blackhawks', created_time=datetime.datetime(2026, 1, 20, 2, 1, 37, 281530, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=31, yes_bid_dollars='0.3100', yes_ask=33, yes_ask_dollars='0.3300', no_bid=67, no_bid_dollars='0.6700', no_ask=69, no_ask_dollars='0.6900', last_price=33, last_price_dollars='0.3300', volume=512, volume_24h=512, result='', can_close_early=True, open_interest=511, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=4964652, liquidity_dollars='49646.5200', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': 'a0e115e4-5a0c-405f-a005-e83ecdc0baa6'}, rules_primary='If CHI Blackhawks wins the Chicago at Carolina professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNHLGAME-26JAN22CHICAR-CAR', event_ticker='KXNHLGAME-26JAN22CHICAR', market_type='binary', title='Chicago at Carolina Winner?', subtitle='', yes_sub_title='CAR Hurricanes', no_sub_title='CAR Hurricanes', created_time=datetime.datetime(2026, 1, 20, 2, 1, 37, 281530, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 20, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 23, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 6, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=69, yes_bid_dollars='0.6900', yes_ask=71, yes_ask_dollars='0.7100', no_bid=29, no_bid_dollars='0.2900', no_ask=31, no_ask_dollars='0.3100', last_price=69, last_price_dollars='0.6900', volume=553, volume_24h=553, result='', can_close_early=True, open_interest=542, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=0, previous_yes_bid_dollars='0.0000', previous_yes_ask=0, previous_yes_ask_dollars='0.0000', previous_price=0, previous_price_dollars='0.0000', liquidity=5069415, liquidity_dollars='50694.1500', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': 'b93573ce-fdb3-4762-a28e-0f2505b1bd97'}, rules_primary='If CAR Hurricanes wins the Chicago at Carolina professional hockey game scheduled for Jan 22, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNHLGAME-26JAN21WSHVAN-WSH', event_ticker='KXNHLGAME-26JAN21WSHVAN', market_type='binary', title='Washington at Vancouver Winner?', subtitle='', yes_sub_title='WSH Capitals', no_sub_title='WSH Capitals', created_time=datetime.datetime(2026, 1, 19, 5, 2, 15, 328338, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 19, 10, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 5, 3, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 22, 6, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 5, 3, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 5, 3, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=58, yes_bid_dollars='0.5800', yes_ask=59, yes_ask_dollars='0.5900', no_bid=41, no_bid_dollars='0.4100', no_ask=42, no_ask_dollars='0.4200', last_price=59, last_price_dollars='0.5900', volume=1419, volume_24h=1267, result='', can_close_early=True, open_interest=1417, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=59, previous_yes_bid_dollars='0.5900', previous_yes_ask=60, previous_yes_ask_dollars='0.6000', previous_price=59, previous_price_dollars='0.5900', liquidity=12615990, liquidity_dollars='126159.9000', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '5b474f02-be1a-4aee-8200-4c4eb6e557e9'}, rules_primary='If WSH Capitals wins the Washington at Vancouver professional hockey game scheduled for Jan 21, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNHLGAME-26JAN21WSHVAN-VAN', event_ticker='KXNHLGAME-26JAN21WSHVAN', market_type='binary', title='Washington at Vancouver Winner?', subtitle='', yes_sub_title='VAN Canucks', no_sub_title='VAN Canucks', created_time=datetime.datetime(2026, 1, 19, 5, 2, 15, 328338, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 19, 10, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 5, 3, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 22, 6, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 5, 3, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 5, 3, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=40, yes_bid_dollars='0.4000', yes_ask=41, yes_ask_dollars='0.4100', no_bid=59, no_bid_dollars='0.5900', no_ask=60, no_ask_dollars='0.6000', last_price=41, last_price_dollars='0.4100', volume=295, volume_24h=294, result='', can_close_early=True, open_interest=288, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=39, previous_yes_bid_dollars='0.3900', previous_yes_ask=44, previous_yes_ask_dollars='0.4400', previous_price=46, previous_price_dollars='0.4600', liquidity=11536467, liquidity_dollars='115364.6700', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '2d6db4a4-99f2-4547-85f3-9913404577f9'}, rules_primary='If VAN Canucks wins the Washington at Vancouver professional hockey game scheduled for Jan 21, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNHLGAME-26JAN21NYISEA-SEA', event_ticker='KXNHLGAME-26JAN21NYISEA', market_type='binary', title='New York I at Seattle Winner?', subtitle='', yes_sub_title='SEA Kraken', no_sub_title='SEA Kraken', created_time=datetime.datetime(2026, 1, 19, 5, 2, 14, 726842, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 19, 10, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 22, 5, 30, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=47, yes_bid_dollars='0.4700', yes_ask=48, yes_ask_dollars='0.4800', no_bid=52, no_bid_dollars='0.5200', no_ask=53, no_ask_dollars='0.5300', last_price=49, last_price_dollars='0.4900', volume=1769, volume_24h=1711, result='', can_close_early=True, open_interest=1767, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=41, previous_yes_bid_dollars='0.4100', previous_yes_ask=55, previous_yes_ask_dollars='0.5500', previous_price=52, previous_price_dollars='0.5200', liquidity=206810728, liquidity_dollars='2068107.2800', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '2ed1104c-eb5a-4175-9f05-0561caaa59d2'}, rules_primary='If SEA Kraken wins the New York I at Seattle professional hockey game scheduled for Jan 21, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNHLGAME-26JAN21NYISEA-NYI', event_ticker='KXNHLGAME-26JAN21NYISEA', market_type='binary', title='New York I at Seattle Winner?', subtitle='', yes_sub_title='NYI Islanders', no_sub_title='NYI Islanders', created_time=datetime.datetime(2026, 1, 19, 5, 2, 14, 726842, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 19, 10, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 22, 5, 30, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=52, yes_bid_dollars='0.5200', yes_ask=53, yes_ask_dollars='0.5300', no_bid=47, no_bid_dollars='0.4700', no_ask=48, no_ask_dollars='0.4800', last_price=53, last_price_dollars='0.5300', volume=347, volume_24h=253, result='', can_close_early=True, open_interest=347, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=42, previous_yes_bid_dollars='0.4200', previous_yes_ask=56, previous_yes_ask_dollars='0.5600', previous_price=58, previous_price_dollars='0.5800', liquidity=206370915, liquidity_dollars='2063709.1500', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '03f52887-5bb7-4b51-954e-433f73474350'}, rules_primary='If NYI Islanders wins the New York I at Seattle professional hockey game scheduled for Jan 21, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNHLGAME-26JAN21PITCGY-PIT', event_ticker='KXNHLGAME-26JAN21PITCGY', market_type='binary', title='Pittsburgh at Calgary Winner?', subtitle='', yes_sub_title='PIT Penguins', no_sub_title='PIT Penguins', created_time=datetime.datetime(2026, 1, 19, 5, 2, 14, 128637, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 19, 10, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 22, 5, 30, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=52, yes_bid_dollars='0.5200', yes_ask=53, yes_ask_dollars='0.5300', no_bid=47, no_bid_dollars='0.4700', no_ask=48, no_ask_dollars='0.4800', last_price=53, last_price_dollars='0.5300', volume=577, volume_24h=415, result='', can_close_early=True, open_interest=576, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=54, previous_yes_bid_dollars='0.5400', previous_yes_ask=55, previous_yes_ask_dollars='0.5500', previous_price=55, previous_price_dollars='0.5500', liquidity=219562340, liquidity_dollars='2195623.4000', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '1b5c6299-90f7-49c7-8617-264610d50488'}, rules_primary='If PIT Penguins wins the Pittsburgh at Calgary professional hockey game scheduled for Jan 21, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNHLGAME-26JAN21PITCGY-CGY', event_ticker='KXNHLGAME-26JAN21PITCGY', market_type='binary', title='Pittsburgh at Calgary Winner?', subtitle='', yes_sub_title='CGY Flames', no_sub_title='CGY Flames', created_time=datetime.datetime(2026, 1, 19, 5, 2, 14, 128637, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 19, 10, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 22, 5, 30, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 5, 2, 30, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=47, yes_bid_dollars='0.4700', yes_ask=49, yes_ask_dollars='0.4900', no_bid=51, no_bid_dollars='0.5100', no_ask=53, no_ask_dollars='0.5300', last_price=49, last_price_dollars='0.4900', volume=1425, volume_24h=1425, result='', can_close_early=True, open_interest=1424, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=48, previous_yes_bid_dollars='0.4800', previous_yes_ask=49, previous_yes_ask_dollars='0.4900', previous_price=0, previous_price_dollars='0.0000', liquidity=217328235, liquidity_dollars='2173282.3500', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': 'ea3554a4-eaa6-4e72-a32f-8388e618133f'}, rules_primary='If CGY Flames wins the Pittsburgh at Calgary professional hockey game scheduled for Jan 21, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNHLGAME-26JAN21DETTOR-TOR', event_ticker='KXNHLGAME-26JAN21DETTOR', market_type='binary', title='Detroit at Toronto Winner?', subtitle='', yes_sub_title='TOR Maple Leafs', no_sub_title='TOR Maple Leafs', created_time=datetime.datetime(2026, 1, 19, 2, 1, 37, 320612, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 19, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 5, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 22, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 5, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 5, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=51, yes_bid_dollars='0.5100', yes_ask=52, yes_ask_dollars='0.5200', no_bid=48, no_bid_dollars='0.4800', no_ask=49, no_ask_dollars='0.4900', last_price=52, last_price_dollars='0.5200', volume=999, volume_24h=928, result='', can_close_early=True, open_interest=996, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=52, previous_yes_bid_dollars='0.5200', previous_yes_ask=55, previous_yes_ask_dollars='0.5500', previous_price=54, previous_price_dollars='0.5400', liquidity=219443657, liquidity_dollars='2194436.5700', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': 'f61f9daa-407b-4c46-96e8-feee19cd6f51'}, rules_primary='If TOR Maple Leafs wins the Detroit at Toronto professional hockey game scheduled for Jan 21, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
# ...
#   Market(ticker='KXNHLGAME-26JAN20BOSDAL-BOS', event_ticker='KXNHLGAME-26JAN20BOSDAL', market_type='binary', title='Boston at Dallas Winner?', subtitle='', yes_sub_title='BOS Bruins', no_sub_title='BOS Bruins', created_time=datetime.datetime(2026, 1, 18, 2, 1, 45, 504841, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 18, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 4, 0, 30, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 21, 3, 30, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 4, 0, 30, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 4, 0, 30, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=0, yes_bid_dollars='0.0000', yes_ask=1, yes_ask_dollars='0.0100', no_bid=99, no_bid_dollars='0.9900', no_ask=100, no_ask_dollars='1.0000', last_price=1, last_price_dollars='0.0100', volume=363231, volume_24h=354262, result='', can_close_early=True, open_interest=274074, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=38, previous_yes_bid_dollars='0.3800', previous_yes_ask=40, previous_yes_ask_dollars='0.4000', previous_price=39, previous_price_dollars='0.3900', liquidity=1224376, liquidity_dollars='12243.7600', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '4163474f-3470-4f0c-8a60-c998e3f93810'}, rules_primary='If BOS Bruins wins the Boston at Dallas professional hockey game scheduled for Jan 20, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNHLGAME-26JAN20BUFNSH-NSH', event_ticker='KXNHLGAME-26JAN20BUFNSH', market_type='binary', title='Buffalo at Nashville Winner?', subtitle='', yes_sub_title='NSH Predators', no_sub_title='NSH Predators', created_time=datetime.datetime(2026, 1, 18, 2, 1, 43, 512219, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 18, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 4, 1, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 21, 4, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 4, 1, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 4, 1, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=12, yes_bid_dollars='0.1200', yes_ask=14, yes_ask_dollars='0.1400', no_bid=86, no_bid_dollars='0.8600', no_ask=88, no_ask_dollars='0.8800', last_price=15, last_price_dollars='0.1500', volume=88777, volume_24h=85329, result='', can_close_early=True, open_interest=60064, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=54, previous_yes_bid_dollars='0.5400', previous_yes_ask=55, previous_yes_ask_dollars='0.5500', previous_price=55, previous_price_dollars='0.5500', liquidity=9350354, liquidity_dollars='93503.5400', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': 'fcfd0b58-cc0a-448e-8f4b-6ddeab8f339f'}, rules_primary='If NSH Predators wins the Buffalo at Nashville professional hockey game scheduled for Jan 20, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNHLGAME-26JAN20BUFNSH-BUF', event_ticker='KXNHLGAME-26JAN20BUFNSH', market_type='binary', title='Buffalo at Nashville Winner?', subtitle='', yes_sub_title='BUF Sabres', no_sub_title='BUF Sabres', created_time=datetime.datetime(2026, 1, 18, 2, 1, 43, 512219, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 18, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 4, 1, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 21, 4, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 4, 1, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 4, 1, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=86, yes_bid_dollars='0.8600', yes_ask=88, yes_ask_dollars='0.8800', no_bid=12, no_bid_dollars='0.1200', no_ask=14, no_ask_dollars='0.1400', last_price=87, last_price_dollars='0.8700', volume=246684, volume_24h=240107, result='', can_close_early=True, open_interest=184157, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=45, previous_yes_bid_dollars='0.4500', previous_yes_ask=46, previous_yes_ask_dollars='0.4600', previous_price=46, previous_price_dollars='0.4600', liquidity=9664937, liquidity_dollars='96649.3700', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '458b20ce-1c62-47d8-8fc4-6f752a2476e7'}, rules_primary='If BUF Sabres wins the Buffalo at Nashville professional hockey game scheduled for Jan 20, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNHLGAME-26JAN20SJTB-TB', event_ticker='KXNHLGAME-26JAN20SJTB', market_type='binary', title='San Jose at Tampa Bay Winner?', subtitle='', yes_sub_title='TB Lightning', no_sub_title='TB Lightning', created_time=datetime.datetime(2026, 1, 18, 2, 1, 42, 479796, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 18, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 4, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 21, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 4, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 4, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=99, yes_bid_dollars='0.9900', yes_ask=100, yes_ask_dollars='1.0000', no_bid=0, no_bid_dollars='0.0000', no_ask=1, no_ask_dollars='0.0100', last_price=99, last_price_dollars='0.9900', volume=300885, volume_24h=298634, result='', can_close_early=True, open_interest=227480, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=71, previous_yes_bid_dollars='0.7100', previous_yes_ask=72, previous_yes_ask_dollars='0.7200', previous_price=72, previous_price_dollars='0.7200', liquidity=658601, liquidity_dollars='6586.0100', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': 'b08e569c-3249-4fcf-bea2-a57ab5e822eb'}, rules_primary='If TB Lightning wins the San Jose at Tampa Bay professional hockey game scheduled for Jan 20, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNHLGAME-26JAN20SJTB-SJ', event_ticker='KXNHLGAME-26JAN20SJTB', market_type='binary', title='San Jose at Tampa Bay Winner?', subtitle='', yes_sub_title='SJ Sharks', no_sub_title='SJ Sharks', created_time=datetime.datetime(2026, 1, 18, 2, 1, 42, 479796, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 18, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 4, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 21, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 4, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 4, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=0, yes_bid_dollars='0.0000', yes_ask=1, yes_ask_dollars='0.0100', no_bid=99, no_bid_dollars='0.9900', no_ask=100, no_ask_dollars='1.0000', last_price=1, last_price_dollars='0.0100', volume=349953, volume_24h=346040, result='', can_close_early=True, open_interest=270763, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=27, previous_yes_bid_dollars='0.2700', previous_yes_ask=28, previous_yes_ask_dollars='0.2800', previous_price=28, previous_price_dollars='0.2800', liquidity=751956, liquidity_dollars='7519.5600', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': 'eb4bc183-5966-40eb-8bdb-3dd922ad1752'}, rules_primary='If SJ Sharks wins the San Jose at Tampa Bay professional hockey game scheduled for Jan 20, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])),
#  (Market(ticker='KXNHLGAME-26JAN20OTTCBJ-OTT', event_ticker='KXNHLGAME-26JAN20OTTCBJ', market_type='binary', title='Ottawa at Columbus Winner?', subtitle='', yes_sub_title='OTT Senators', no_sub_title='OTT Senators', created_time=datetime.datetime(2026, 1, 18, 2, 1, 38, 202521, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 18, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 4, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 21, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 4, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 4, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=99, yes_bid_dollars='0.9900', yes_ask=100, yes_ask_dollars='1.0000', no_bid=0, no_bid_dollars='0.0000', no_ask=1, no_ask_dollars='0.0100', last_price=99, last_price_dollars='0.9900', volume=129263, volume_24h=127990, result='', can_close_early=True, open_interest=97499, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=49, previous_yes_bid_dollars='0.4900', previous_yes_ask=51, previous_yes_ask_dollars='0.5100', previous_price=51, previous_price_dollars='0.5100', liquidity=659624, liquidity_dollars='6596.2400', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': 'a2478063-2ded-4657-923b-e59de696ad21'}, rules_primary='If OTT Senators wins the Ottawa at Columbus professional hockey game scheduled for Jan 20, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]),
#   Market(ticker='KXNHLGAME-26JAN20OTTCBJ-CBJ', event_ticker='KXNHLGAME-26JAN20OTTCBJ', market_type='binary', title='Ottawa at Columbus Winner?', subtitle='', yes_sub_title='CBJ Blue Jackets', no_sub_title='CBJ Blue Jackets', created_time=datetime.datetime(2026, 1, 18, 2, 1, 38, 202521, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 18, 7, 6, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 4, 0, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 21, 3, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 4, 0, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 4, 0, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=30, status='active', response_price_units='usd_cent', yes_bid=0, yes_bid_dollars='0.0000', yes_ask=1, yes_ask_dollars='0.0100', no_bid=99, no_bid_dollars='0.9900', no_ask=100, no_ask_dollars='1.0000', last_price=1, last_price_dollars='0.0100', volume=145765, volume_24h=145231, result='', can_close_early=True, open_interest=104630, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=49, previous_yes_bid_dollars='0.4900', previous_yes_ask=50, previous_yes_ask_dollars='0.5000', previous_price=50, previous_price_dollars='0.5000', liquidity=1364299, liquidity_dollars='13642.9900', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'hockey_team': '253e2161-4b9b-4580-88e7-a25b9f6cf8af'}, rules_primary='If CBJ Blue Jackets wins the Ottawa at Columbus professional hockey game scheduled for Jan 20, 2026, then the market resolves to Yes.', rules_secondary='', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')]))]

# %%
valid = kalshi_wrapped.GetMarketByTicker(soccer_markets, "KXUCLGAME-26JAN21QARSGE")

# %%
target = valid

# %%
import time, math, threading
from collections import deque
from datetime import datetime
import uuid
import os
import logging

# %matplotlib widget
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# ---------- logging setup ----------
def setup_logger(notebook_dir: str) -> logging.Logger:
    """Create a logger that writes to a log file with date and UUID"""
    log_dir = os.path.join(notebook_dir, "logs")
    os.makedirs(log_dir, exist_ok=True)
    
    session_id = str(uuid.uuid4())[:8]
    date_str = datetime.now().strftime("%Y-%m-%d")
    log_filename = f"arb_monitor_{date_str}_{session_id}.log"
    log_path = os.path.join(log_dir, log_filename)
    
    logger = logging.getLogger(f"arb_monitor_{session_id}")
    logger.setLevel(logging.DEBUG)
    
    # Clear existing handlers
    logger.handlers = []
    
    # File handler
    fh = logging.FileHandler(log_path)
    fh.setLevel(logging.DEBUG)
    fh.setFormatter(logging.Formatter('%(asctime)s | %(levelname)s | %(message)s'))
    logger.addHandler(fh)
    
    # Console handler for important messages
    ch = logging.StreamHandler()
    ch.setLevel(logging.INFO)
    ch.setFormatter(logging.Formatter('%(message)s'))
    logger.addHandler(ch)
    
    logger.info(f"=== Logging started: {log_path} ===")
    return logger

# Get notebook directory for logging
NOTEBOOK_DIR = os.path.dirname(os.path.abspath("__file__")) if "__file__" in dir() else os.getcwd()

# ---------- helpers ----------
def _to_float(x):
    if x is None:
        return None
    try:
        return float(x)
    except (TypeError, ValueError):
        return None

def _round_up_cent(x: float) -> float:
    return math.ceil(x * 100.0) / 100.0

def kalshi_fee_total(C: int, P: float, maker: bool = False) -> float:
    # Taker: round_up(0.07*C*P*(1-P)), Maker: round_up(0.0175*C*P*(1-P))
    rate = 0.0175 if maker else 0.07
    return _round_up_cent(rate * C * P * (1.0 - P))

def fee_per_contract(C: int, P: float, maker: bool = False) -> float:
    return kalshi_fee_total(C, P, maker=maker) / C

def all_in_buy_cost(P_ask: float, C: int, maker: bool = False) -> float:
    # cost per contract to buy now at ask, including fees
    return P_ask + fee_per_contract(C, P_ask, maker=maker)

def all_in_sell_proceeds(P_bid: float, C: int, maker: bool = False) -> float:
    # proceeds per contract to sell now at bid, net of fees
    return P_bid - fee_per_contract(C, P_bid, maker=maker)

# ---------- live monitor ----------
class LiveArbMonitor:
    def __init__(
        self,
        client,
        ticker_1: str,       # market1
        ticker_2: str,       # market2
        poll_period_ms: int = 500,
        contract_size: int = 100,
        entry_maker: bool = False,   # if you cross spread, this should be False (taker)
        exit_maker: bool = False,    # same idea for selling
        min_edge: float = 0.01,      # for routing prints (optional)
        arb_floor: float = 0.002,    # only print arb if pnl >= this ($/contract)
        profit_floor: float = 0.002, # only print dutch-to-settle if profit >= this
        history: int = 600,
        auto_trade: bool = False,    # enable automatic trading
        max_position: int = 10,      # max contracts per leg
        trade_size: int = 1,         # contracts per trade
        min_trade_pnl: float = 0.005, # minimum pnl to execute trade ($/contract)
        logger: logging.Logger = None,
    ):
        self.client = client
        self.t_1 = ticker_1
        self.t_2 = ticker_2
        
        # Setup logger
        self.logger = logger or setup_logger(NOTEBOOK_DIR)
        self.logger.info(f"LiveArbMonitor initialized: {ticker_1} vs {ticker_2}")
        self.logger.info(f"Settings: auto_trade={auto_trade}, trade_size={trade_size}, max_position={max_position}")
        self.logger.info(f"Thresholds: min_trade_pnl={min_trade_pnl}, arb_floor={arb_floor}, profit_floor={profit_floor}")
        self.client = client
        self.t_1 = ticker_1
        self.t_2 = ticker_2

        self.poll_period_s = poll_period_ms / 1000.0
        self.C = contract_size
        self.entry_maker = entry_maker
        self.exit_maker = exit_maker
        self.min_edge = min_edge
        self.arb_floor = arb_floor
        self.profit_floor = profit_floor
        
        # Trading controls
        self.auto_trade = auto_trade
        self.max_position = max_position
        self.trade_size = trade_size
        self.min_trade_pnl = min_trade_pnl
        
        # Position tracking
        self.positions = {
            f"{ticker_1}_yes": 0,
            f"{ticker_1}_no": 0,
            f"{ticker_2}_yes": 0,
            f"{ticker_2}_no": 0,
        }
        self.trade_history = []
        self.last_trade_time = 0
        self.trade_cooldown = 2.0  # seconds between trades

        self.lock = threading.Lock()
        self.stop_evt = threading.Event()
        self.t0 = time.time()

        self.x = deque(maxlen=history)

        # routing edges (entry-cost only; still useful)
        self.edge_1 = deque(maxlen=history)
        self.edge_2 = deque(maxlen=history)

        # "dutch to settle" profit (entry only)
        self.profit_to_settle = deque(maxlen=history)

        # cross-market arb pnl per contract (buy cheap exposure, sell expensive exposure)
        self.arb_pnl_1 = deque(maxlen=history)
        self.arb_pnl_2 = deque(maxlen=history)

        # entry fees per contract (at asks)
        self.f_1_yes = deque(maxlen=history)
        self.f_1_no  = deque(maxlen=history)
        self.f_2_yes = deque(maxlen=history)
        self.f_2_no  = deque(maxlen=history)

        # best-action tracking
        self.best_kind = "NO_TRADE"
        self.best_since = time.time()

        self.last_meta = {
            "team1": "Team 1", "team2": "Team 2",
            "t1_yes_a": None, "t1_no_a": None, "t2_yes_a": None, "t2_no_a": None,
            "t1_yes_b": None, "t1_no_b": None, "t2_yes_b": None, "t2_no_b": None,
            "arb_leg_1_buy": "", "arb_leg_1_sell": "",
            "arb_leg_2_buy": "", "arb_leg_2_sell": "",
            "best_action": "NO_TRADE",
            "best_value": 0.0,
            "best_age_s": 0.0,
        }

        self.last_sig = {"team1": None, "team2": None, "dutch": None}
        self.th = threading.Thread(target=self._run, daemon=True)

    def start(self):
        self.th.start()
        return self

    def stop(self):
        self.stop_evt.set()
        self.th.join(timeout=2.0)
        self.logger.info("Monitor stopped")
    
    def _execute_trade(self, ticker: str, side: str, action: str, price: float, quantity: int):
        """Execute a single trade leg"""
        try:
            # side = "yes" or "no", action = "buy" or "sell"
            order_params = {
                "ticker": ticker,
                "action": action,
                "side": side,
                "count": quantity,
                "type": "market" if not self.entry_maker else "limit",
            }
            
            if self.entry_maker:
                order_params["yes_price"] = int(price * 100) if side == "yes" else None
                order_params["no_price"] = int(price * 100) if side == "no" else None
            
            ts = datetime.now().strftime("%H:%M:%S")
            msg = f"[{ts}] EXECUTING: {action.upper()} {quantity} {side.upper()} {ticker} @ {price:.3f}"
            print(msg)
            self.logger.info(msg)
            self.logger.debug(f"Order params: {order_params}")
            
            # Place order through client
            response = self.client.create_order(**order_params)
            
            # Update position tracking
            pos_key = f"{ticker}_{side}"
            if action == "buy":
                self.positions[pos_key] += quantity
            else:
                self.positions[pos_key] -= quantity
            
            # Record trade
            trade_record = {
                "time": time.time(),
                "ticker": ticker,
                "side": side,
                "action": action,
                "quantity": quantity,
                "price": price,
                "response": str(response),
            }
            self.trade_history.append(trade_record)
            
            msg = f"[{ts}] ✓ Trade executed. Position {pos_key}: {self.positions[pos_key]}"
            print(msg)
            self.logger.info(msg)
            self.logger.debug(f"Response: {response}")
            return True
            
        except Exception as e:
            msg = f"[TRADE ERROR] {ticker} {side} {action}: {e}"
            print(msg)
            self.logger.error(msg, exc_info=True)
            return False
    
    def _can_trade(self, ticker: str, side: str, quantity: int):
        """Check if trade is within position limits"""
        pos_key = f"{ticker}_{side}"
        new_position = self.positions[pos_key] + quantity
        can = abs(new_position) <= self.max_position
        if not can:
            self.logger.debug(f"Position limit check FAILED: {pos_key} current={self.positions[pos_key]} + {quantity} = {new_position}, max={self.max_position}")
        return can
    
    def _execute_arb(self, buy_ticker: str, buy_side: str, buy_price: float,
                     sell_ticker: str, sell_side: str, sell_price: float, 
                     expected_pnl: float, team_name: str):
        """Execute a cross-market arb trade"""
        ts = datetime.now().strftime("%H:%M:%S")
        
        # Check cooldown
        time_since_last = time.time() - self.last_trade_time
        if time_since_last < self.trade_cooldown:
            self.logger.debug(f"Cooldown active: {time_since_last:.1f}s < {self.trade_cooldown}s")
            return False
        
        # Check position limits
        if not self._can_trade(buy_ticker, buy_side, self.trade_size):
            msg = f"[{ts}] Position limit reached for {buy_ticker} {buy_side}"
            print(msg)
            self.logger.warning(msg)
            return False
        if not self._can_trade(sell_ticker, sell_side, -self.trade_size):
            msg = f"[{ts}] Position limit reached for {sell_ticker} {sell_side}"
            print(msg)
            self.logger.warning(msg)
            return False
        
        msg = f"\n[{ts}] ═══ EXECUTING ARB: {team_name} exposure ═══"
        print(msg)
        self.logger.info(msg)
        msg = f"Expected PnL: ${expected_pnl:.4f}/contract, Total: ${expected_pnl * self.trade_size:.2f}"
        print(msg)
        self.logger.info(msg)
        
        # Execute buy leg first
        buy_success = self._execute_trade(buy_ticker, buy_side, "buy", buy_price, self.trade_size)
        if not buy_success:
            msg = f"[{ts}] ✗ Buy leg failed, aborting arb"
            print(msg)
            self.logger.error(msg)
            return False
        
        # Execute sell leg
        sell_success = self._execute_trade(sell_ticker, sell_side, "sell", sell_price, self.trade_size)
        if not sell_success:
            msg = f"[{ts}] ⚠ Sell leg failed! Holding unhedged position!"
            print(msg)
            self.logger.error(msg)
            return False
        
        self.last_trade_time = time.time()
        msg = f"[{ts}] ═══ ARB COMPLETE ═══\n"
        print(msg)
        self.logger.info(msg)
        return True
    
    def _execute_dutch_settle(self, leg1_ticker: str, leg1_side: str, leg1_price: float,
                               leg2_ticker: str, leg2_side: str, leg2_price: float,
                               expected_profit: float):
        """Execute dutch auction to settlement trade"""
        ts = datetime.now().strftime("%H:%M:%S")
        
        # Check cooldown
        time_since_last = time.time() - self.last_trade_time
        if time_since_last < self.trade_cooldown:
            self.logger.debug(f"Cooldown active: {time_since_last:.1f}s < {self.trade_cooldown}s")
            return False
        
        # Check position limits
        if not self._can_trade(leg1_ticker, leg1_side, self.trade_size):
            msg = f"[{ts}] Position limit reached for {leg1_ticker} {leg1_side}"
            print(msg)
            self.logger.warning(msg)
            return False
        if not self._can_trade(leg2_ticker, leg2_side, self.trade_size):
            msg = f"[{ts}] Position limit reached for {leg2_ticker} {leg2_side}"
            print(msg)
            self.logger.warning(msg)
            return False
        
        msg = f"\n[{ts}] ═══ EXECUTING DUTCH-TO-SETTLE ═══"
        print(msg)
        self.logger.info(msg)
        msg = f"Expected Profit: ${expected_profit:.4f}/contract, Total: ${expected_profit * self.trade_size:.2f}"
        print(msg)
        self.logger.info(msg)
        
        # Execute both buy legs
        leg1_success = self._execute_trade(leg1_ticker, leg1_side, "buy", leg1_price, self.trade_size)
        if not leg1_success:
            msg = f"[{ts}] ✗ Leg 1 failed, aborting"
            print(msg)
            self.logger.error(msg)
            return False
        
        leg2_success = self._execute_trade(leg2_ticker, leg2_side, "buy", leg2_price, self.trade_size)
        if not leg2_success:
            msg = f"[{ts}] ⚠ Leg 2 failed! Holding partial position!"
            print(msg)
            self.logger.error(msg)
            return False
        
        self.last_trade_time = time.time()
        msg = f"[{ts}] ═══ DUTCH-TO-SETTLE COMPLETE ═══\n"
        print(msg)
        self.logger.info(msg)
        return True

    def _run(self):
        while not self.stop_evt.is_set():
            try:
                m_1 = self.client.get_market(self.t_1)
                m_2 = self.client.get_market(self.t_2)

                d_1 = m_1.market.model_dump()
                d_2 = m_2.market.model_dump()

                team1 = d_1.get("yes_sub_title", "Team 1")
                team2 = d_2.get("yes_sub_title", "Team 2")

                # asks
                t1_yes_a = _to_float(d_1.get("yes_ask_dollars"))
                t1_no_a  = _to_float(d_1.get("no_ask_dollars"))
                t2_yes_a = _to_float(d_2.get("yes_ask_dollars"))
                t2_no_a  = _to_float(d_2.get("no_ask_dollars"))

                # bids
                t1_yes_b = _to_float(d_1.get("yes_bid_dollars"))
                t1_no_b  = _to_float(d_1.get("no_bid_dollars"))
                t2_yes_b = _to_float(d_2.get("yes_bid_dollars"))
                t2_no_b  = _to_float(d_2.get("no_bid_dollars"))

                if any(v is None for v in [t1_yes_a, t1_no_a, t2_yes_a, t2_no_a]):
                    self.logger.warning(f"Missing asks: t1_yes_a={t1_yes_a}, t1_no_a={t1_no_a}, t2_yes_a={t2_yes_a}, t2_no_a={t2_no_a}")
                    time.sleep(self.poll_period_s)
                    continue
                
                # Log market state periodically (every 10 ticks)
                if len(self.x) % 10 == 0:
                    self.logger.debug(f"Market state: t1_yes a/b={t1_yes_a}/{t1_yes_b}, t1_no a/b={t1_no_a}/{t1_no_b}, t2_yes a/b={t2_yes_a}/{t2_yes_b}, t2_no a/b={t2_no_a}/{t2_no_b}")

                # ----- entry all-in costs (per contract) -----
                c_1_yes = all_in_buy_cost(t1_yes_a, self.C, maker=self.entry_maker)
                c_1_no  = all_in_buy_cost(t1_no_a,  self.C, maker=self.entry_maker)
                c_2_yes = all_in_buy_cost(t2_yes_a, self.C, maker=self.entry_maker)
                c_2_no  = all_in_buy_cost(t2_no_a,  self.C, maker=self.entry_maker)

                # routing edges (same exposure, different instrument)
                edge_1 = c_1_yes - c_2_no     # Team1 exposure: YES Team1 vs NO Team2
                edge_2 = c_2_yes - c_1_no     # Team2 exposure: YES Team2 vs NO Team1

                # dutch-to-settle
                best_1 = min(c_1_yes, c_2_no)
                best_2 = min(c_2_yes, c_1_no)
                profit_to_settle = 1.0 - (best_1 + best_2)

                # ----- cross-market arb PnL (buy cheap exposure, sell expensive exposure) -----
                arb_pnl_1 = None
                arb_buy_1 = arb_sell_1 = ""

                if (t1_yes_b is not None) and (t2_no_b is not None):
                    buy_candidates = [
                        ("BUY YES", self.t_1, t1_yes_a, c_1_yes),
                        ("BUY NO",  self.t_2, t2_no_a, c_2_no),
                    ]
                    sell_candidates = [
                        ("SELL YES", self.t_1, t1_yes_b, all_in_sell_proceeds(t1_yes_b, self.C, maker=self.exit_maker)),
                        ("SELL NO",  self.t_2, t2_no_b, all_in_sell_proceeds(t2_no_b, self.C, maker=self.exit_maker)),
                    ]
                    buy_leg = min(buy_candidates, key=lambda x: x[3])
                    sell_leg = max(sell_candidates, key=lambda x: x[3])
                    arb_pnl_1 = sell_leg[3] - buy_leg[3]
                    arb_buy_1 = f"{buy_leg[0]} {buy_leg[1]} @ {buy_leg[2]:.3f}"
                    arb_sell_1 = f"{sell_leg[0]} {sell_leg[1]} @ {sell_leg[2]:.3f}"

                arb_pnl_2 = None
                arb_buy_2 = arb_sell_2 = ""

                if (t2_yes_b is not None) and (t1_no_b is not None):
                    buy_candidates = [
                        ("BUY YES", self.t_2, t2_yes_a, c_2_yes),
                        ("BUY NO",  self.t_1, t1_no_a,  c_1_no),
                    ]
                    sell_candidates = [
                        ("SELL YES", self.t_2, t2_yes_b, all_in_sell_proceeds(t2_yes_b, self.C, maker=self.exit_maker)),
                        ("SELL NO",  self.t_1, t1_no_b,  all_in_sell_proceeds(t1_no_b,  self.C, maker=self.exit_maker)),
                    ]
                    buy_leg = min(buy_candidates, key=lambda x: x[3])
                    sell_leg = max(sell_candidates, key=lambda x: x[3])
                    arb_pnl_2 = sell_leg[3] - buy_leg[3]
                    arb_buy_2 = f"{buy_leg[0]} {buy_leg[1]} @ {buy_leg[2]:.3f}"
                    arb_sell_2 = f"{sell_leg[0]} {sell_leg[1]} @ {sell_leg[2]:.3f}"

                # ----- choose best action NOW (this tick) -----
                candidates = []

                if (arb_pnl_1 is not None) and (arb_pnl_1 >= self.arb_floor):
                    candidates.append(("ARB_TEAM1", arb_pnl_1, f"{arb_buy_1} ; {arb_sell_1}"))

                if (arb_pnl_2 is not None) and (arb_pnl_2 >= self.arb_floor):
                    candidates.append(("ARB_TEAM2", arb_pnl_2, f"{arb_buy_2} ; {arb_sell_2}"))

                if profit_to_settle >= self.profit_floor:
                    candidates.append(("DUTCH_SETTLE", profit_to_settle, "Buy both cheapest legs; hold to settlement"))

                now = time.time()
                if candidates:
                    best_kind, best_val, best_detail = max(candidates, key=lambda t: t[1])
                    best_action_str = f"{best_kind}: {best_detail}"
                else:
                    best_kind, best_val, best_action_str = "NO_TRADE", 0.0, "NO_TRADE: No action clears thresholds"

                if best_kind != self.best_kind:
                    self.best_kind = best_kind
                    self.best_since = now
                best_age_s = now - self.best_since

                with self.lock:
                    self.x.append(now - self.t0)
                    self.edge_1.append(edge_1)
                    self.edge_2.append(edge_2)
                    self.profit_to_settle.append(profit_to_settle)

                    self.arb_pnl_1.append(arb_pnl_1 if arb_pnl_1 is not None else float("nan"))
                    self.arb_pnl_2.append(arb_pnl_2 if arb_pnl_2 is not None else float("nan"))

                    self.f_1_yes.append(fee_per_contract(self.C, t1_yes_a, maker=self.entry_maker))
                    self.f_1_no.append( fee_per_contract(self.C, t1_no_a,  maker=self.entry_maker))
                    self.f_2_yes.append(fee_per_contract(self.C, t2_yes_a, maker=self.entry_maker))
                    self.f_2_no.append( fee_per_contract(self.C, t2_no_a,  maker=self.entry_maker))

                    self.last_meta.update({
                        "team1": team1, "team2": team2,
                        "t1_yes_a": t1_yes_a, "t1_no_a": t1_no_a, "t2_yes_a": t2_yes_a, "t2_no_a": t2_no_a,
                        "t1_yes_b": t1_yes_b, "t1_no_b": t1_no_b, "t2_yes_b": t2_yes_b, "t2_no_b": t2_no_b,
                        "arb_leg_1_buy": arb_buy_1, "arb_leg_1_sell": arb_sell_1,
                        "arb_leg_2_buy": arb_buy_2, "arb_leg_2_sell": arb_sell_2,
                        "best_action": best_action_str,
                        "best_value": float(best_val),
                        "best_age_s": float(best_age_s),
                    })

                # ----- prints: what to do -----
                ts = datetime.now().strftime("%H:%M:%S")

                if abs(edge_1) >= self.min_edge:
                    sig = (f"[{ts}] {team1} exposure cheaper via "
                           f"{'BUY NO '+self.t_2 if edge_1>0 else 'BUY YES '+self.t_1} "
                           f"(edge={abs(edge_1):.4f} $/contract, fees incl.)")
                    if sig != self.last_sig["team1"]:
                        print(sig)
                        self.last_sig["team1"] = sig

                if abs(edge_2) >= self.min_edge:
                    sig = (f"[{ts}] {team2} exposure cheaper via "
                           f"{'BUY NO '+self.t_1 if edge_2>0 else 'BUY YES '+self.t_2} "
                           f"(edge={abs(edge_2):.4f} $/contract, fees incl.)")
                    if sig != self.last_sig["team2"]:
                        print(sig)
                        self.last_sig["team2"] = sig

                if (arb_pnl_1 is not None) and (arb_pnl_1 >= self.arb_floor):
                    print(f"[{ts}] ARB {team1} exposure: {arb_buy_1} ; {arb_sell_1} "
                          f"=> pnl≈{arb_pnl_1:.4f} $/contract (fees entry+exit incl.)")

                if (arb_pnl_2 is not None) and (arb_pnl_2 >= self.arb_floor):
                    print(f"[{ts}] ARB {team2} exposure: {arb_buy_2} ; {arb_sell_2} "
                          f"=> pnl≈{arb_pnl_2:.4f} $/contract (fees entry+exit incl.)")

                if profit_to_settle >= self.profit_floor:
                    print(f"[{ts}] DUTCH-to-settle: profit≈{profit_to_settle:.4f} $/contract "
                          f"(assumes {team1}/{team2} are perfect complements)")

                # ----- AUTO TRADING: Execute best action if enabled -----
                if self.auto_trade and candidates:
                    best_kind, best_val, _ = max(candidates, key=lambda t: t[1])
                    
                    self.logger.debug(f"AUTO_TRADE check: best_kind={best_kind}, best_val={best_val:.5f}, min_trade_pnl={self.min_trade_pnl}")
                    
                    if best_val >= self.min_trade_pnl:
                        self.logger.info(f"TRADE SIGNAL: {best_kind} with pnl={best_val:.5f} >= {self.min_trade_pnl}")
                        
                        if best_kind == "ARB_TEAM1" and arb_pnl_1 >= self.min_trade_pnl:
                            # Parse which legs to trade from the candidates
                            buy_candidates = [
                                (self.t_1, "yes", t1_yes_a),
                                (self.t_2, "no", t2_no_a),
                            ]
                            sell_candidates = [
                                (self.t_1, "yes", t1_yes_b),
                                (self.t_2, "no", t2_no_b),
                            ]
                            self.logger.debug(f"ARB_TEAM1 buy_candidates: {buy_candidates}")
                            self.logger.debug(f"ARB_TEAM1 sell_candidates: {sell_candidates}")
                            
                            buy_leg = min(buy_candidates, key=lambda x: all_in_buy_cost(x[2], self.C, self.entry_maker))
                            sell_leg = max(sell_candidates, key=lambda x: all_in_sell_proceeds(x[2], self.C, self.exit_maker))
                            
                            self.logger.info(f"Executing ARB_TEAM1: BUY {buy_leg}, SELL {sell_leg}")
                            
                            self._execute_arb(
                                buy_leg[0], buy_leg[1], buy_leg[2],
                                sell_leg[0], sell_leg[1], sell_leg[2],
                                arb_pnl_1, team1
                            )
                        
                        elif best_kind == "ARB_TEAM2" and arb_pnl_2 >= self.min_trade_pnl:
                            buy_candidates = [
                                (self.t_2, "yes", t2_yes_a),
                                (self.t_1, "no", t1_no_a),
                            ]
                            sell_candidates = [
                                (self.t_2, "yes", t2_yes_b),
                                (self.t_1, "no", t1_no_b),
                            ]
                            self.logger.debug(f"ARB_TEAM2 buy_candidates: {buy_candidates}")
                            self.logger.debug(f"ARB_TEAM2 sell_candidates: {sell_candidates}")
                            
                            buy_leg = min(buy_candidates, key=lambda x: all_in_buy_cost(x[2], self.C, self.entry_maker))
                            sell_leg = max(sell_candidates, key=lambda x: all_in_sell_proceeds(x[2], self.C, self.exit_maker))
                            
                            self.logger.info(f"Executing ARB_TEAM2: BUY {buy_leg}, SELL {sell_leg}")
                            
                            self._execute_arb(
                                buy_leg[0], buy_leg[1], buy_leg[2],
                                sell_leg[0], sell_leg[1], sell_leg[2],
                                arb_pnl_2, team2
                            )
                        
                        elif best_kind == "DUTCH_SETTLE" and profit_to_settle >= self.min_trade_pnl:
                            # Buy both cheapest legs
                            leg1 = (self.t_1, "yes", t1_yes_a) if c_1_yes < c_2_no else (self.t_2, "no", t2_no_a)
                            leg2 = (self.t_2, "yes", t2_yes_a) if c_2_yes < c_1_no else (self.t_1, "no", t1_no_a)
                            
                            self.logger.info(f"Executing DUTCH_SETTLE: leg1={leg1}, leg2={leg2}")
                            
                            self._execute_dutch_settle(
                                leg1[0], leg1[1], leg1[2],
                                leg2[0], leg2[1], leg2[2],
                                profit_to_settle
                            )
                    else:
                        self.logger.debug(f"Below threshold: {best_val:.5f} < {self.min_trade_pnl}")
                elif self.auto_trade:
                    self.logger.debug(f"No candidates this tick. arb_pnl_1={arb_pnl_1}, arb_pnl_2={arb_pnl_2}, profit_to_settle={profit_to_settle:.5f}")
                    self.logger.debug(f"Bids: t1_yes_b={t1_yes_b}, t1_no_b={t1_no_b}, t2_yes_b={t2_yes_b}, t2_no_b={t2_no_b}")

            except Exception as e:
                msg = f"[poll error] {e}"
                print(msg)
                self.logger.error(msg, exc_info=True)

            time.sleep(self.poll_period_s)

# ---------- plot wiring ----------
def live_plot_pair(
    event_pair,
    poll_period_ms=500,
    contract_size=100,
    entry_maker=False,
    exit_maker=False,
    min_edge=0.01,
    arb_floor=0.002,
    profit_floor=0.002,
    history=600,
    refresh_ms=250,
    auto_trade=False,        # NEW: enable auto trading
    max_position=10,         # NEW: max contracts per leg
    trade_size=1,            # NEW: contracts per trade
    min_trade_pnl=0.005,     # NEW: min pnl to execute
):
    market1, market2 = event_pair
    t_1 = market1.model_dump()["ticker"]
    t_2 = market2.model_dump()["ticker"]
    
    # Setup logger for this session
    logger = setup_logger(NOTEBOOK_DIR)
    logger.info(f"Starting live_plot_pair for {t_1} vs {t_2}")

    mon = LiveArbMonitor(
        client=kalshi_wrapped.GetClient(),
        ticker_1=t_1,
        ticker_2=t_2,
        poll_period_ms=poll_period_ms,
        contract_size=contract_size,
        entry_maker=entry_maker,
        exit_maker=exit_maker,
        min_edge=min_edge,
        arb_floor=arb_floor,
        profit_floor=profit_floor,
        history=history,
        auto_trade=auto_trade,
        max_position=max_position,
        trade_size=trade_size,
        min_trade_pnl=min_trade_pnl,
        logger=logger,
    ).start()

    fig, ax = plt.subplots()

    # left axis: profitability signals
    (l_edge_1,) = ax.plot([], [], label="Team1 routing edge")
    (l_edge_2,) = ax.plot([], [], label="Team2 routing edge")
    (l_arb_1,) = ax.plot([], [], label="ARB pnl Team1 exposure")
    (l_arb_2,) = ax.plot([], [], label="ARB pnl Team2 exposure")
    (l_dutch,) = ax.plot([], [], label="profit_to_settle")

    ax.axhline(0.0)
    ax.axhline(arb_floor)
    ax.axhline(profit_floor)

    ax.set_xlabel("seconds")
    ax.set_ylabel("$/contract (fees included)")
    title = ax.set_title("Starting...")

    # overlay text for best action + age
    action_text = ax.text(
        0.02, 0.02, "",
        transform=ax.transAxes,
        va="bottom", ha="left",
    )

    # right axis: entry fees at asks
    axf = ax.twinx()
    (f1,) = axf.plot([], [], linestyle="--", label="fee Team1 YES@ask")
    (f2,) = axf.plot([], [], linestyle="--", label="fee Team1 NO@ask")
    (f3,) = axf.plot([], [], linestyle="--", label="fee Team2 YES@ask")
    (f4,) = axf.plot([], [], linestyle="--", label="fee Team2 NO@ask")
    axf.set_ylabel("fee per contract ($)")

    leg_left = ax.legend(loc="upper left")
    leg_right = axf.legend(loc="upper right")
    last_names = {"team1": None, "team2": None}

    def _update(_frame):
        nonlocal leg_left

        with mon.lock:
            xs = list(mon.x)
            e_1 = list(mon.edge_1)
            e_2 = list(mon.edge_2)
            a_1 = list(mon.arb_pnl_1)
            a_2 = list(mon.arb_pnl_2)
            dutch = list(mon.profit_to_settle)

            ff1 = list(mon.f_1_yes)
            ff2 = list(mon.f_1_no)
            ff3 = list(mon.f_2_yes)
            ff4 = list(mon.f_2_no)

            meta = dict(mon.last_meta)

        if not xs:
            return (l_edge_1, l_edge_2, l_arb_1, l_arb_2, l_dutch, f1, f2, f3, f4, title, action_text, leg_left, leg_right)

        l_edge_1.set_data(xs, e_1)
        l_edge_2.set_data(xs, e_2)
        l_arb_1.set_data(xs, a_1)
        l_arb_2.set_data(xs, a_2)
        l_dutch.set_data(xs, dutch)

        f1.set_data(xs, ff1)
        f2.set_data(xs, ff2)
        f3.set_data(xs, ff3)
        f4.set_data(xs, ff4)

        ax.set_xlim(xs[0], xs[-1])

        # autoscale left axis
        ys = [v for series in (e_1, e_2, a_1, a_2, dutch)
              for v in series
              if (v is not None and not (isinstance(v, float) and math.isnan(v)))]
        if ys:
            ymin = min(min(ys), 0.0) - 0.01
            ymax = max(max(ys), arb_floor, profit_floor, 0.0) + 0.01
            ax.set_ylim(ymin, ymax)

        # autoscale fee axis (stable)
        if ff1 and ff2 and ff3 and ff4:
            fmin = min(ff1[-1], ff2[-1], ff3[-1], ff4[-1])
            fmax = max(ff1[-1], ff2[-1], ff3[-1], ff4[-1])
            axf.set_ylim(max(0.0, fmin - 0.001), fmax + 0.001)

        # update legend labels to include team names
        if meta["team1"] != last_names["team1"] or meta["team2"] != last_names["team2"]:
            l_edge_1.set_label(f"{meta['team1']} routing edge: all-in(YES {t_1}) - all-in(NO {t_2})")
            l_edge_2.set_label(f"{meta['team2']} routing edge: all-in(YES {t_2}) - all-in(NO {t_1})")
            l_arb_1.set_label(f"ARB pnl {meta['team1']} exposure (buy cheap rep, sell rich rep)")
            l_arb_2.set_label(f"ARB pnl {meta['team2']} exposure (buy cheap rep, sell rich rep)")
            l_dutch.set_label("profit_to_settle (entry only)")

            leg_left.remove()
            leg_left = ax.legend(loc="upper left")
            last_names["team1"] = meta["team1"]
            last_names["team2"] = meta["team2"]

        title.set_text(
            f"{meta['team1']} (t1={t_1}) YES a/b={meta['t1_yes_a']:.3f}/{(meta['t1_yes_b'] if meta['t1_yes_b'] is not None else float('nan')):.3f} | "
            f"{meta['team2']} (t2={t_2}) YES a/b={meta['t2_yes_a']:.3f}/{(meta['t2_yes_b'] if meta['t2_yes_b'] is not None else float('nan')):.3f} | "
            f"Team1 arb: {meta['arb_leg_1_buy']} ; {meta['arb_leg_1_sell']}"
        )

        action_text.set_text(
            f"Best action: {meta.get('best_action','')}\n"
            f"Value: {meta.get('best_value', 0.0):.4f} $/contract | "
            f"Best-for: {meta.get('best_age_s', 0.0):.1f}s"
        )

        return (l_edge_1, l_edge_2, l_arb_1, l_arb_2, l_dutch, f1, f2, f3, f4, title, action_text, leg_left, leg_right)

    ani = FuncAnimation(fig, _update, interval=refresh_ms, blit=False, cache_frame_data=False)
    plt.show()
    return mon, ani

# Usage:
# Monitor only (no trading):
# mon, ani = live_plot_pair(event_pair, poll_period_ms=500, contract_size=100,
#                           entry_maker=False, exit_maker=False,
#                           min_edge=0.01, arb_floor=0.002, profit_floor=0.002)
#
# Auto-trade when profitable:
# mon, ani = live_plot_pair(event_pair, poll_period_ms=300, contract_size=1000,
#                           auto_trade=True, trade_size=5, max_position=20,
#                           min_trade_pnl=0.005, arb_floor=0.003, profit_floor=0.003)
#
# Check positions: mon.positions
# Check trade history: mon.trade_history
# Stop: mon.stop()

# %% [markdown]
# ## Soccer 3-Way Monitor (Win / Loss / Draw)
#
# Unlike NHL (2 outcomes), soccer has 3 possible outcomes:
# - **Team 1 Wins**
# - **Team 2 Wins**
# - **Draw**
#
# ### Arbitrage Opportunities:
# 1. **Dutch-to-Settle**: Buy YES on all 3 outcomes. One must pay out $1. Profit if total cost < $1.
# 2. **Cross-outcome Arb**: If bid on one outcome > ask on another, exploit the mispricing.
# 3. **Routing**: Find cheapest way to get exposure to a specific outcome.

# %%
# ============================================================================
# SOCCER 3-WAY ARB MONITOR (Win / Loss / Draw)
# ============================================================================

class SoccerArbMonitor:
    """
    Monitor for soccer markets with 3 outcomes: Team1 Win, Team2 Win, Draw.
    
    Key opportunities:
    1. Dutch-to-Settle: Buy all 3 outcomes, one pays $1. Profit if sum < $1.
    2. Cross-Outcome Arb: Sell overpriced outcome, buy underpriced.
    """
    
    def __init__(
        self,
        client,
        ticker_team1: str,    # Market for Team 1 to win
        ticker_team2: str,    # Market for Team 2 to win  
        ticker_draw: str,     # Market for Draw
        poll_period_ms: int = 500,
        contract_size: int = 100,
        entry_maker: bool = False,
        exit_maker: bool = False,
        dutch_floor: float = 0.002,   # min profit for dutch-to-settle
        arb_floor: float = 0.002,     # min pnl for cross-outcome arb
        history: int = 600,
        auto_trade: bool = False,
        max_position: int = 10,
        trade_size: int = 1,
        min_trade_pnl: float = 0.005,
        logger: logging.Logger = None,
    ):
        self.client = client
        self.t_1 = ticker_team1
        self.t_2 = ticker_team2
        self.t_d = ticker_draw
        
        self.logger = logger or setup_logger(NOTEBOOK_DIR)
        self.logger.info(f"SoccerArbMonitor initialized: {ticker_team1} vs {ticker_team2} vs {ticker_draw}")
        self.logger.info(f"Settings: auto_trade={auto_trade}, trade_size={trade_size}, max_position={max_position}")
        
        self.poll_period_s = poll_period_ms / 1000.0
        self.C = contract_size
        self.entry_maker = entry_maker
        self.exit_maker = exit_maker
        self.dutch_floor = dutch_floor
        self.arb_floor = arb_floor
        
        # Trading controls
        self.auto_trade = auto_trade
        self.max_position = max_position
        self.trade_size = trade_size
        self.min_trade_pnl = min_trade_pnl
        
        # Position tracking
        self.positions = {
            f"{ticker_team1}_yes": 0,
            f"{ticker_team2}_yes": 0,
            f"{ticker_draw}_yes": 0,
        }
        self.trade_history = []
        self.last_trade_time = 0
        self.trade_cooldown = 2.0
        
        self.lock = threading.Lock()
        self.stop_evt = threading.Event()
        self.t0 = time.time()
        
        self.x = deque(maxlen=history)
        
        # Track prices
        self.team1_ask = deque(maxlen=history)
        self.team2_ask = deque(maxlen=history)
        self.draw_ask = deque(maxlen=history)
        self.team1_bid = deque(maxlen=history)
        self.team2_bid = deque(maxlen=history)
        self.draw_bid = deque(maxlen=history)
        
        # Profitability metrics
        self.dutch_profit = deque(maxlen=history)  # 1 - sum(all asks with fees)
        self.best_arb_pnl = deque(maxlen=history)  # best cross-outcome arb
        
        self.last_meta = {
            "team1_name": "Team 1", "team2_name": "Team 2",
            "t1_ask": None, "t2_ask": None, "td_ask": None,
            "t1_bid": None, "t2_bid": None, "td_bid": None,
            "dutch_profit": 0.0,
            "best_arb": "",
            "best_arb_pnl": 0.0,
            "best_action": "NO_TRADE",
        }
        
        self.th = threading.Thread(target=self._run, daemon=True)
    
    def start(self):
        self.th.start()
        return self
    
    def stop(self):
        self.stop_evt.set()
        self.th.join(timeout=2.0)
        self.logger.info("Monitor stopped")
    
    def _execute_trade(self, ticker: str, side: str, action: str, price: float, quantity: int):
        """Execute a single trade"""
        try:
            # Kalshi API expects prices in cents (integer)
            price_cents = int(round(price * 100))
            
            order_params = {
                "ticker": ticker,
                "action": action,
                "side": side,
                "count": quantity,
                "type": "limit",  # Use limit orders for reliability
            }
            
            # Set price based on side
            if side == "yes":
                order_params["yes_price"] = price_cents
            else:
                order_params["no_price"] = price_cents
            
            ts = datetime.now().strftime("%H:%M:%S")
            msg = f"[{ts}] EXECUTING: {action.upper()} {quantity} {side.upper()} {ticker} @ {price:.3f} ({price_cents}¢)"
            print(msg)
            self.logger.info(msg)
            self.logger.debug(f"Order params: {order_params}")
            
            response = self.client.create_order(**order_params)
            
            pos_key = f"{ticker}_{side}"
            if action == "buy":
                self.positions[pos_key] = self.positions.get(pos_key, 0) + quantity
            else:
                self.positions[pos_key] = self.positions.get(pos_key, 0) - quantity
            
            self.trade_history.append({
                "time": time.time(),
                "ticker": ticker,
                "side": side,
                "action": action,
                "quantity": quantity,
                "price": price,
            })
            
            msg = f"[{ts}] ✓ Trade executed."
            print(msg)
            self.logger.info(msg)
            self.logger.debug(f"Response: {response}")
            return True
            
        except Exception as e:
            msg = f"[TRADE ERROR] {ticker} {side} {action}: {e}"
            print(msg)
            self.logger.error(msg, exc_info=True)
            return False
    
    def _can_trade(self, ticker: str, side: str, quantity: int):
        pos_key = f"{ticker}_{side}"
        new_position = self.positions.get(pos_key, 0) + quantity
        return abs(new_position) <= self.max_position
    
    def _execute_dutch(self, legs: list, expected_profit: float):
        """Execute dutch-to-settle: buy all 3 outcomes"""
        ts = datetime.now().strftime("%H:%M:%S")
        
        if time.time() - self.last_trade_time < self.trade_cooldown:
            return False
        
        # Check all position limits
        for ticker, price in legs:
            if not self._can_trade(ticker, "yes", self.trade_size):
                self.logger.warning(f"Position limit for {ticker}")
                return False
        
        msg = f"\n[{ts}] ═══ EXECUTING DUTCH-TO-SETTLE (3-way) ═══"
        print(msg)
        self.logger.info(msg)
        print(f"Expected Profit: ${expected_profit:.4f}/contract")
        
        for ticker, price in legs:
            if not self._execute_trade(ticker, "yes", "buy", price, self.trade_size):
                self.logger.error(f"Failed on {ticker}, partial position!")
                return False
        
        self.last_trade_time = time.time()
        print(f"[{ts}] ═══ DUTCH COMPLETE ═══\n")
        return True
    
    def _execute_arb(self, buy_ticker: str, buy_price: float, 
                     sell_ticker: str, sell_price: float, expected_pnl: float):
        """Execute cross-outcome arb: buy cheap, sell rich"""
        ts = datetime.now().strftime("%H:%M:%S")
        
        if time.time() - self.last_trade_time < self.trade_cooldown:
            return False
        
        if not self._can_trade(buy_ticker, "yes", self.trade_size):
            return False
        if not self._can_trade(sell_ticker, "yes", -self.trade_size):
            return False
        
        msg = f"\n[{ts}] ═══ EXECUTING CROSS-OUTCOME ARB ═══"
        print(msg)
        self.logger.info(msg)
        print(f"Expected PnL: ${expected_pnl:.4f}/contract")
        
        if not self._execute_trade(buy_ticker, "yes", "buy", buy_price, self.trade_size):
            return False
        if not self._execute_trade(sell_ticker, "yes", "sell", sell_price, self.trade_size):
            self.logger.error("Sell leg failed! Unhedged position!")
            return False
        
        self.last_trade_time = time.time()
        print(f"[{ts}] ═══ ARB COMPLETE ═══\n")
        return True
    
    def _run(self):
        while not self.stop_evt.is_set():
            try:
                # Fetch all 3 markets
                m_1 = self.client.get_market(self.t_1)
                m_2 = self.client.get_market(self.t_2)
                m_d = self.client.get_market(self.t_d)
                
                d_1 = m_1.market.model_dump()
                d_2 = m_2.market.model_dump()
                d_d = m_d.market.model_dump()
                
                team1_name = d_1.get("yes_sub_title", "Team 1")
                team2_name = d_2.get("yes_sub_title", "Team 2")
                
                # Get asks and bids
                t1_ask = _to_float(d_1.get("yes_ask_dollars"))
                t2_ask = _to_float(d_2.get("yes_ask_dollars"))
                td_ask = _to_float(d_d.get("yes_ask_dollars"))
                
                t1_bid = _to_float(d_1.get("yes_bid_dollars"))
                t2_bid = _to_float(d_2.get("yes_bid_dollars"))
                td_bid = _to_float(d_d.get("yes_bid_dollars"))
                
                if any(v is None for v in [t1_ask, t2_ask, td_ask]):
                    self.logger.debug("Missing asks, skipping tick")
                    time.sleep(self.poll_period_s)
                    continue
                
                # Calculate all-in costs (with fees)
                c_1 = all_in_buy_cost(t1_ask, self.C, self.entry_maker)
                c_2 = all_in_buy_cost(t2_ask, self.C, self.entry_maker)
                c_d = all_in_buy_cost(td_ask, self.C, self.entry_maker)
                
                # Dutch-to-settle profit: $1 payout - total cost
                total_cost = c_1 + c_2 + c_d
                dutch_profit = 1.0 - total_cost
                
                # Cross-outcome arb: find best bid vs best ask
                # If we can sell one outcome for more than buying another, profit!
                arb_candidates = []
                
                outcomes = [
                    (self.t_1, t1_ask, t1_bid, c_1, "Team1"),
                    (self.t_2, t2_ask, t2_bid, c_2, "Team2"),
                    (self.t_d, td_ask, td_bid, c_d, "Draw"),
                ]
                
                for i, (buy_t, buy_ask, _, buy_cost, buy_name) in enumerate(outcomes):
                    for j, (sell_t, _, sell_bid, _, sell_name) in enumerate(outcomes):
                        if i == j or sell_bid is None:
                            continue
                        sell_proceeds = all_in_sell_proceeds(sell_bid, self.C, self.exit_maker)
                        pnl = sell_proceeds - buy_cost
                        if pnl > 0:
                            arb_candidates.append({
                                "buy_ticker": buy_t,
                                "buy_price": buy_ask,
                                "buy_cost": buy_cost,
                                "buy_name": buy_name,
                                "sell_ticker": sell_t,
                                "sell_price": sell_bid,
                                "sell_proceeds": sell_proceeds,
                                "sell_name": sell_name,
                                "pnl": pnl,
                            })
                
                best_arb = max(arb_candidates, key=lambda x: x["pnl"]) if arb_candidates else None
                best_arb_pnl = best_arb["pnl"] if best_arb else 0.0
                best_arb_str = ""
                if best_arb:
                    best_arb_str = f"BUY {best_arb['buy_name']} @ {best_arb['buy_price']:.3f}, SELL {best_arb['sell_name']} @ {best_arb['sell_price']:.3f}"
                
                # Store data
                now = time.time()
                with self.lock:
                    self.x.append(now - self.t0)
                    self.team1_ask.append(t1_ask)
                    self.team2_ask.append(t2_ask)
                    self.draw_ask.append(td_ask)
                    self.team1_bid.append(t1_bid if t1_bid else float("nan"))
                    self.team2_bid.append(t2_bid if t2_bid else float("nan"))
                    self.draw_bid.append(td_bid if td_bid else float("nan"))
                    self.dutch_profit.append(dutch_profit)
                    self.best_arb_pnl.append(best_arb_pnl)
                    
                    self.last_meta.update({
                        "team1_name": team1_name, "team2_name": team2_name,
                        "t1_ask": t1_ask, "t2_ask": t2_ask, "td_ask": td_ask,
                        "t1_bid": t1_bid, "t2_bid": t2_bid, "td_bid": td_bid,
                        "dutch_profit": dutch_profit,
                        "best_arb": best_arb_str,
                        "best_arb_pnl": best_arb_pnl,
                    })
                
                # Print signals
                ts = datetime.now().strftime("%H:%M:%S")
                
                if dutch_profit >= self.dutch_floor:
                    print(f"[{ts}] DUTCH 3-WAY: Buy all 3 outcomes for ${total_cost:.3f}, "
                          f"profit=${dutch_profit:.4f}/contract (holds to settlement)")
                
                if best_arb and best_arb["pnl"] >= self.arb_floor:
                    print(f"[{ts}] ARB: {best_arb_str} => pnl=${best_arb['pnl']:.4f}/contract")
                
                # Determine best action
                candidates = []
                if dutch_profit >= self.dutch_floor:
                    candidates.append(("DUTCH", dutch_profit))
                if best_arb and best_arb["pnl"] >= self.arb_floor:
                    candidates.append(("ARB", best_arb["pnl"]))
                
                if candidates:
                    best_kind, best_val = max(candidates, key=lambda x: x[1])
                    self.last_meta["best_action"] = f"{best_kind}: ${best_val:.4f}"
                else:
                    self.last_meta["best_action"] = "NO_TRADE"
                
                # Auto-trade
                if self.auto_trade and candidates:
                    best_kind, best_val = max(candidates, key=lambda x: x[1])
                    
                    if best_val >= self.min_trade_pnl:
                        if best_kind == "DUTCH":
                            legs = [(self.t_1, t1_ask), (self.t_2, t2_ask), (self.t_d, td_ask)]
                            self._execute_dutch(legs, dutch_profit)
                        elif best_kind == "ARB" and best_arb:
                            self._execute_arb(
                                best_arb["buy_ticker"], best_arb["buy_price"],
                                best_arb["sell_ticker"], best_arb["sell_price"],
                                best_arb["pnl"]
                            )
                
            except Exception as e:
                self.logger.error(f"Poll error: {e}", exc_info=True)
            
            time.sleep(self.poll_period_s)


def live_plot_soccer(
    ticker_team1: str,
    ticker_team2: str,
    ticker_draw: str,
    poll_period_ms=500,
    contract_size=100,
    entry_maker=False,
    exit_maker=False,
    dutch_floor=0.002,
    arb_floor=0.002,
    history=600,
    refresh_ms=250,
    auto_trade=False,
    max_position=10,
    trade_size=1,
    min_trade_pnl=0.005,
):
    """Live plot for soccer 3-way markets"""
    
    logger = setup_logger(NOTEBOOK_DIR)
    logger.info(f"Starting soccer monitor: {ticker_team1} vs {ticker_team2} vs {ticker_draw}")
    
    mon = SoccerArbMonitor(
        client=kalshi_wrapped.GetClient(),
        ticker_team1=ticker_team1,
        ticker_team2=ticker_team2,
        ticker_draw=ticker_draw,
        poll_period_ms=poll_period_ms,
        contract_size=contract_size,
        entry_maker=entry_maker,
        exit_maker=exit_maker,
        dutch_floor=dutch_floor,
        arb_floor=arb_floor,
        history=history,
        auto_trade=auto_trade,
        max_position=max_position,
        trade_size=trade_size,
        min_trade_pnl=min_trade_pnl,
        logger=logger,
    ).start()
    
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8), sharex=True)
    
    # Top plot: Prices (asks as solid, bids as dashed)
    l_t1_ask, = ax1.plot([], [], label="Team1 YES ask", color="blue")
    l_t2_ask, = ax1.plot([], [], label="Team2 YES ask", color="red")
    l_td_ask, = ax1.plot([], [], label="Draw YES ask", color="green")
    l_t1_bid, = ax1.plot([], [], "--", label="Team1 YES bid", color="blue", alpha=0.5)
    l_t2_bid, = ax1.plot([], [], "--", label="Team2 YES bid", color="red", alpha=0.5)
    l_td_bid, = ax1.plot([], [], "--", label="Draw YES bid", color="green", alpha=0.5)
    
    ax1.set_ylabel("Price ($)")
    ax1.legend(loc="upper left", fontsize=8)
    title = ax1.set_title("Soccer 3-Way Monitor")
    
    # Bottom plot: Profitability
    l_dutch, = ax2.plot([], [], label="Dutch Profit (3-way)", color="purple", linewidth=2)
    l_arb, = ax2.plot([], [], label="Best Arb PnL", color="orange", linewidth=2)
    ax2.axhline(0, color="black", linestyle="-", alpha=0.3)
    ax2.axhline(dutch_floor, color="purple", linestyle="--", alpha=0.5, label=f"Dutch floor: {dutch_floor}")
    ax2.axhline(arb_floor, color="orange", linestyle="--", alpha=0.5, label=f"Arb floor: {arb_floor}")
    
    ax2.set_xlabel("Seconds")
    ax2.set_ylabel("Profit ($/contract)")
    ax2.legend(loc="upper left", fontsize=8)
    
    action_text = ax2.text(0.02, 0.95, "", transform=ax2.transAxes, va="top", fontsize=10)
    
    def _update(_frame):
        with mon.lock:
            xs = list(mon.x)
            t1a = list(mon.team1_ask)
            t2a = list(mon.team2_ask)
            tda = list(mon.draw_ask)
            t1b = list(mon.team1_bid)
            t2b = list(mon.team2_bid)
            tdb = list(mon.draw_bid)
            dutch = list(mon.dutch_profit)
            arb = list(mon.best_arb_pnl)
            meta = dict(mon.last_meta)
        
        if not xs:
            return ()
        
        # Update price lines
        l_t1_ask.set_data(xs, t1a)
        l_t2_ask.set_data(xs, t2a)
        l_td_ask.set_data(xs, tda)
        l_t1_bid.set_data(xs, t1b)
        l_t2_bid.set_data(xs, t2b)
        l_td_bid.set_data(xs, tdb)
        
        # Update profit lines
        l_dutch.set_data(xs, dutch)
        l_arb.set_data(xs, arb)
        
        # Autoscale
        ax1.set_xlim(xs[0], xs[-1])
        all_prices = [p for p in t1a + t2a + tda + t1b + t2b + tdb 
                      if p is not None and not math.isnan(p)]
        if all_prices:
            ax1.set_ylim(min(all_prices) - 0.02, max(all_prices) + 0.02)
        
        ax2.set_xlim(xs[0], xs[-1])
        all_profits = [p for p in dutch + arb if not math.isnan(p)]
        if all_profits:
            ymin = min(min(all_profits), 0) - 0.005
            ymax = max(max(all_profits), dutch_floor, arb_floor) + 0.01
            ax2.set_ylim(ymin, ymax)
        
        # Update title and text
        title.set_text(
            f"{meta['team1_name']} ask={meta['t1_ask']:.3f} | "
            f"{meta['team2_name']} ask={meta['t2_ask']:.3f} | "
            f"Draw ask={meta['td_ask']:.3f}"
        )
        
        action_text.set_text(
            f"Best: {meta['best_action']}\n"
            f"Dutch: ${meta['dutch_profit']:.4f} | Arb: ${meta['best_arb_pnl']:.4f}\n"
            f"{meta['best_arb']}"
        )
        
        return ()
    
    ani = FuncAnimation(fig, _update, interval=refresh_ms, blit=False, cache_frame_data=False)
    plt.tight_layout()
    plt.show()
    return mon, ani

print("Soccer 3-Way Monitor defined!")
print("Usage: mon, ani = live_plot_soccer(ticker_team1, ticker_team2, ticker_draw, ...)")
# Out:
# Soccer 3-Way Monitor defined!
# Usage: mon, ani = live_plot_soccer(ticker_team1, ticker_team2, ticker_draw, ...)

# %%
# Find soccer market tickers for a specific match
# Soccer markets typically have 3 outcomes: Team1 Win, Team2 Win, Draw

def find_soccer_tickers(markets, match_keyword: str = None):
    """
    Group soccer markets by event and find Win/Loss/Draw tickers.
    
    Returns dict: {event_name: {"team1": ticker, "team2": ticker, "draw": ticker}}
    """
    from collections import defaultdict
    
    # Group by event ticker prefix (remove outcome suffix)
    events = defaultdict(dict)
    
    for m in markets:
        d = m.model_dump()
        ticker = d["ticker"]
        subtitle = d.get("yes_sub_title", "").lower()
        title = d.get("title", "")
        
        # Extract event prefix (everything before team/draw identifier)
        # e.g., "KXUCLGAME-26JAN21QARSGE" -> "KXUCLGAME-26JAN21"
        parts = ticker.rsplit("-", 1)
        if len(parts) == 2:
            event_prefix = parts[0]
            outcome_code = parts[1]
        else:
            event_prefix = ticker
            outcome_code = ""
        
        # Determine if this is team1, team2, or draw
        if "draw" in subtitle or "tie" in subtitle:
            events[event_prefix]["draw"] = ticker
            events[event_prefix]["draw_name"] = d.get("yes_sub_title", "Draw")
        else:
            # It's a team outcome
            if "team1" not in events[event_prefix]:
                events[event_prefix]["team1"] = ticker
                events[event_prefix]["team1_name"] = d.get("yes_sub_title", "Team 1")
            elif "team2" not in events[event_prefix]:
                events[event_prefix]["team2"] = ticker
                events[event_prefix]["team2_name"] = d.get("yes_sub_title", "Team 2")
        
        events[event_prefix]["title"] = title
    
    # Filter to complete 3-way markets
    complete = {k: v for k, v in events.items() 
                if "team1" in v and "team2" in v and "draw" in v}
    
    if match_keyword:
        complete = {k: v for k, v in complete.items() 
                    if match_keyword.lower() in v.get("title", "").lower()}
    
    return complete

# Show available soccer matches
soccer_events = find_soccer_tickers(soccer_markets)
print(f"Found {len(soccer_events)} complete 3-way soccer markets:\n")

for event_id, info in list(soccer_events.items())[:5]:
    print(f"📍 {info.get('title', event_id)}")
    print(f"   Team1: {info['team1']} ({info.get('team1_name', '')})")
    print(f"   Team2: {info['team2']} ({info.get('team2_name', '')})")
    print(f"   Draw:  {info['draw']} ({info.get('draw_name', '')})")
    print()
# Out:
# Found 9 complete 3-way soccer markets:
#
# 📍 Newcastle vs Eindhoven Winner?
#    Team1: KXUCLGAME-26JAN21NEWPSV-PSV (Eindhoven)
#    Team2: KXUCLGAME-26JAN21NEWPSV-NEW (Newcastle)
#    Draw:  KXUCLGAME-26JAN21NEWPSV-TIE (Tie)
#
# 📍 Juventus vs SL Benfica Winner?
#    Team1: KXUCLGAME-26JAN21JUVBEN-JUV (Juventus)
#    Team2: KXUCLGAME-26JAN21JUVBEN-BEN (SL Benfica)
#    Draw:  KXUCLGAME-26JAN21JUVBEN-TIE (Tie)
#
# 📍 Chelsea vs Pafos Winner?
#    Team1: KXUCLGAME-26JAN21CFCPAF-PAF (Pafos)
#    Team2: KXUCLGAME-26JAN21CFCPAF-CFC (Chelsea)
#    Draw:  KXUCLGAME-26JAN21CFCPAF-TIE (Tie)
#
# 📍 Atalanta vs Bilbao Winner?
#    Team1: KXUCLGAME-26JAN21ATAATH-ATH (Bilbao)
#    Team2: KXUCLGAME-26JAN21ATAATH-ATA (Atalanta)
#    Draw:  KXUCLGAME-26JAN21ATAATH-TIE (Tie)
#
# 📍 Galatasaray vs Atletico Winner?
#    Team1: KXUCLGAME-26JAN21GALATM-GAL (Galatasaray)
#    Team2: KXUCLGAME-26JAN21GALATM-ATM (Atletico)
#    Draw:  KXUCLGAME-26JAN21GALATM-TIE (Tie)

# %%
# Select a soccer match and start the monitor
# Pick the first available match or specify one

if soccer_events:
    # Get first event
    first_event = list(soccer_events.values())[0]
    
    soccer_target = {
        "team1": first_event["team1"],
        "team2": first_event["team2"],
        "draw": first_event["draw"],
    }
    
    print(f"Selected match:")
    print(f"  Team1: {first_event.get('team1_name')} -> {soccer_target['team1']}")
    print(f"  Team2: {first_event.get('team2_name')} -> {soccer_target['team2']}")
    print(f"  Draw: {soccer_target['draw']}")
else:
    print("No soccer markets found. Run the cell above to fetch markets.")
# Out:
# Selected match:
#   Team1: Eindhoven -> KXUCLGAME-26JAN21NEWPSV-PSV
#   Team2: Newcastle -> KXUCLGAME-26JAN21NEWPSV-NEW
#   Draw: KXUCLGAME-26JAN21NEWPSV-TIE

# %%
valid = kalshi_wrapped.GetMarketByTicker(soccer_markets, "KXUCLGAME-26JAN21BMUUSG")

# %%
valid
# Out:
# Market(ticker='KXUCLGAME-26JAN21BMUUSG-USG', event_ticker='KXUCLGAME-26JAN21BMUUSG', market_type='binary', title='Bayern Munich vs Union Gilloise Winner?', subtitle='', yes_sub_title='Union Gilloise', no_sub_title='Union Gilloise', created_time=datetime.datetime(2026, 1, 7, 1, 1, 50, 2269, tzinfo=TzInfo(0)), open_time=datetime.datetime(2026, 1, 7, 13, 0, tzinfo=TzInfo(0)), close_time=datetime.datetime(2026, 2, 4, 20, 0, tzinfo=TzInfo(0)), expected_expiration_time=datetime.datetime(2026, 1, 21, 23, 0, tzinfo=TzInfo(0)), expiration_time=datetime.datetime(2026, 2, 4, 20, 0, tzinfo=TzInfo(0)), latest_expiration_time=datetime.datetime(2026, 2, 4, 20, 0, tzinfo=TzInfo(0)), settlement_timer_seconds=500, status='active', response_price_units='usd_cent', yes_bid=3, yes_bid_dollars='0.0300', yes_ask=5, yes_ask_dollars='0.0500', no_bid=95, no_bid_dollars='0.9500', no_ask=97, no_ask_dollars='0.9700', last_price=5, last_price_dollars='0.0500', volume=20116, volume_24h=13189, result='', can_close_early=True, open_interest=17620, notional_value=100, notional_value_dollars='1.0000', previous_yes_bid=3, previous_yes_bid_dollars='0.0300', previous_yes_ask=5, previous_yes_ask_dollars='0.0500', previous_price=5, previous_price_dollars='0.0500', liquidity=5708142, liquidity_dollars='57081.4200', settlement_value=None, settlement_value_dollars=None, settlement_ts=None, expiration_value='', fee_waiver_expiration_time=None, early_close_condition='This market will close and expire after a winner is declared.', tick_size=1, strike_type='structured', floor_strike=None, cap_strike=None, functional_strike=None, custom_strike={'soccer_team': '491593c8-10a4-4c69-94a0-05e363d48d27'}, rules_primary='If Union Gilloise wins the Bayern Munich vs Union Gilloise professional UCL soccer game originally scheduled for Jan 21, 2026 after 90 minutes plus stoppage time (does not include extra time or penalties), then the market resolves to Yes.', rules_secondary='The following market refers to the Bayern Munich vs Union Gilloise professional UCL soccer game originally scheduled for Jan 21, 2026 after 90 minutes plus stoppage time (does not include extra time or penalties). If the game ends in a tie, the market called "Tie" resolves to Yes. If the game is cancelled or rescheduled to over two weeks away, the market will resolve to a fair price in accordance with the rules.', mve_collection_ticker=None, mve_selected_legs=None, primary_participant_key=None, price_level_structure='linear_cent', price_ranges=[PriceRange(start='0.0000', end='1.0000', step='0.0100')])

# %%
soccer_target["team1"]
# Out:
# 'KXUCLGAME-26JAN21NEWPSV-PSV'

# %%
# Run the soccer 3-way monitor
# Set auto_trade=True to enable automatic trading

mon_soccer, ani_soccer = live_plot_soccer(
    ticker_team1="KXUCLGAME-26JAN21BMUUSG-BMU",
    ticker_team2="KXUCLGAME-26JAN21BMUUSG-USG",
    ticker_draw=soccer_target["draw"],
    poll_period_ms=60,
    contract_size=200,
    auto_trade=True,        # ← SET TO True TO ENABLE LIVE TRADING
    trade_size=6,
    max_position=20,
    min_trade_pnl=0.003,
    dutch_floor=0.003,      # Only dutch-to-settle (true arbitrage)
)
# Out:
# === Logging started: /home/russell-c/Documents/trading/fresh/tradingutils/notebooks/logs/arb_monitor_2026-01-20_ddfc65f7.log ===
# Starting soccer monitor: KXUCLGAME-26JAN21BMUUSG-BMU vs KXUCLGAME-26JAN21BMUUSG-USG vs KXUCLGAME-26JAN21NEWPSV-TIE
# SoccerArbMonitor initialized: KXUCLGAME-26JAN21BMUUSG-BMU vs KXUCLGAME-26JAN21BMUUSG-USG vs KXUCLGAME-26JAN21NEWPSV-TIE
# Settings: auto_trade=True, trade_size=6, max_position=20
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Check positions and trade history for soccer monitor
if 'mon_soccer' in dir():
    print("Current Positions:")
    for pos, qty in mon_soccer.positions.items():
        if qty != 0:
            print(f"  {pos}: {qty} contracts")
    
    if not any(mon_soccer.positions.values()):
        print("  (No positions)")
    
    print(f"\nTrade History: {len(mon_soccer.trade_history)} trades")
    for trade in mon_soccer.trade_history[-5:]:
        print(f"  {trade['action'].upper()} {trade['quantity']} {trade['ticker']} @ {trade['price']:.3f}")
# Out:
# Current Positions:
#   (No positions)
#
# Trade History: 0 trades

# %% [markdown]
# ## Auto-Trading Enabled
#
# Set `auto_trade=True` to automatically execute trades when profitable opportunities are detected:
# - `trade_size`: contracts per trade
# - `max_position`: maximum contracts per leg (position limit)
# - `min_trade_pnl`: minimum profit per contract to execute ($/contract)
# - `arb_floor` and `profit_floor`: thresholds for identifying opportunities
#
# The monitor will execute trades automatically and track positions in `mon.positions` and `mon.trade_history`.

# %%
# Enable auto-trading with conservative parameters
mon, ani = live_plot_pair(
    target, 
    poll_period_ms=150, 
    contract_size=200,
    auto_trade=True,           # ← ENABLE AUTO-TRADING
    trade_size=2,              # trade 2 contracts at a time
    max_position=10,           # max 10 contracts per leg
    min_trade_pnl=0.003,       # only trade if pnl ≥ $0.005/contract
    arb_floor=0.003,           # arb threshold
    profit_floor=0.003,        # dutch-to-settle threshold
    entry_maker=False,
    exit_maker=False,
    min_edge=0.01
)
# Out:
# [18:35:00] ═══ EXECUTING CROSS-OUTCOME ARB ═══
# [18:35:00] EXECUTING: BUY 6 YES KXUCLGAME-26JAN21BMUUSG-USG @ 0.050 (5¢)
# [18:35:00] ARB: BUY Team2 @ 0.050, SELL Team1 @ 0.880 => pnl=$0.8193/contract
#
# [18:35:00] ═══ EXECUTING CROSS-OUTCOME ARB ═══
# Expected PnL: $0.8193/contract
# [18:35:00] EXECUTING: BUY 6 YES KXUCLGAME-26JAN21BMUUSG-USG @ 0.050 (5¢)
# [18:35:00] ✓ Trade executed.
# [18:35:00] ✓ Trade executed.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Enable auto-trading with conservative parameters
# ----> 2 mon, ani = live_plot_pair(
#       3     target,
#       4     poll_period_ms=150,
#       5     contract_size=200,
#       6     auto_trade=True,           # ← ENABLE AUTO-TRADING
#       7     trade_size=2,              # trade 2 contracts at a time
#       8     max_position=10,           # max 10 contracts per leg
#       9     min_trade_pnl=0.003,       # only trade if pnl ≥ $0.005/contract
#      10     arb_floor=0.003,           # arb threshold
#      11     profit_floor=0.003,        # dutch-to-settle threshold
#      12     entry_maker=False,
#      13     exit_maker=False,
#      14     min_edge=0.01
#      15 )
#
# Cell In[7], line 617, in live_plot_pair(event_pair, poll_period_ms, contract_size, entry_maker, exit_maker, min_edge, arb_floor, profit_floor, history, refresh_ms, auto_trade, max_position, trade_size, min_trade_pnl)
#     601 def live_plot_pair(
#     602     event_pair,
#     603     poll_period_ms=500,
#    (...)    615     min_trade_pnl=0.005,     # NEW: min pnl to execute
#     616 ):
# --> 617     market1, market2 = event_pair
#     618     t_1 = market1.model_dump()["ticker"]
#     619     t_2 = market2.model_dump()["ticker"]
#
# ValueError: too many values to unpack (expected 2)
# [18:35:00] EXECUTING: SELL 6 YES KXUCLGAME-26JAN21BMUUSG-BMU @ 0.880 (88¢)
# [18:35:00] EXECUTING: SELL 6 YES KXUCLGAME-26JAN21BMUUSG-BMU @ 0.880 (88¢)

# %%
# Check current positions
print("Current Positions:")
for ticker_side, quantity in mon.positions.items():
    if quantity != 0:
        print(f"  {ticker_side}: {quantity} contracts")
# Out:
# Current Positions:

# %%
# View trade history
import pandas as pd
if mon.trade_history:
    df = pd.DataFrame(mon.trade_history)
    df['time'] = pd.to_datetime(df['time'], unit='s')
    print(f"\nExecuted {len(df)} trades:")
    print(df[['time', 'ticker', 'side', 'action', 'quantity', 'price']].to_string(index=False))
else:
    print("No trades executed yet")
# Out:
# No trades executed yet
